# %%
import requests
from requests import Response
aqi_url = 'https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate desc&format=JSON'

res:Response = requests.get(aqi_url)
if res.status_code == 200:
    print("下載成功")
else:
    print("下載失敗")

#自訂的欄位驗証
from pydantic import BaseModel,Field,field_validator

class Site(BaseModel):
    site_name:str = Field(alias='sitename')
    county:str
    aqi:int
    status:str
    pm25:float = Field(alias='pm2.5')
    so2:float
    co:float

    @field_validator("pm25",'so2', 'co',mode='before')
    @classmethod
    def whitespace_to_zero(cls,value:str)->str:
        if value == '':
            return '0.0'
        else:
            return value

class AQI(BaseModel):
    records:list[Site]

data1:AQI = AQI.model_validate_json(res.text)
for item in data1.records:
    print(item)
# Out:
# 下載成功
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=5.0 so2=0.3 co=0.13
# site_name='大甲（日南國小）' county='臺中市' aqi=49 status='良好' pm25=19.0 so2=0.8 co=0.2
# site_name='新北(樹林)' county='新北市' aqi=51 status='普通' pm25=14.0 so2=0.2 co=0.43
# site_name='屏東（琉球）' county='屏東縣' aqi=74 status='普通' pm25=12.0 so2=0.7 co=0.23
# site_name='臺南（麻豆）' county='臺南市' aqi=48 status='良好' pm25=10.0 so2=0.4 co=0.19
# site_name='高雄（湖內）' county='高雄市' aqi=45 status='良好' pm25=7.0 so2=0.3 co=0.19
# site_name='彰化（員林）' county='彰化縣' aqi=67 status='普通' pm25=18.0 so2=1.4 co=0.46
# site_name='大城' county='彰化縣' aqi=101 status='對敏感族群不健康' pm25=12.0 so2=1.2 co=0.14
# site_name='富貴角' county='新北市' aqi=67 status='普通' pm25=12.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=77 status='普通' pm25=13.0 so2=1.5 co=0.22
# site_name='關山' county='臺東縣' aqi=39 status='良好' pm25=16.0 so2=1.0 co=0.21
# site_name='馬公' county='澎湖縣' aqi=61 status='普通' pm25=7.0 so2=0.8 co=0.18
# site_name='金門' county='金門縣' aqi=122 status='對敏感族群不健康' pm25=17.0 so2=1.9 co=0.24
# site_name='馬祖' county='連江縣' aqi=87 status='普通' pm25=9.0 so2=0.9 co=0.15
# site_name='埔里' county='南投縣' aqi=31 status='良好' pm25=9.0 so2=0.7 co=0.34
# site_name='復興' county='高雄市' aqi=49 status='良好' pm25=9.0 so2=0.7 co=0.41
# site_name='永和' county='新北市' aqi=52 status='普通' pm25=20.0 so2=1.2 co=0.46
# site_name='竹山' county='南投縣' aqi=64 status='普通' pm25=25.0 so2=1.3 co=0.22
# site_name='中壢' county='桃園市' aqi=49 status='良好' pm25=14.0 so2=1.5 co=1.13
# site_name='三重' county='新北市' aqi=50 status='良好' pm25=14.0 so2=1.4 co=1.1
# site_name='冬山' county='宜蘭縣' aqi=43 status='良好' pm25=10.0 so2=0.6 co=0.22
# site_name='宜蘭' county='宜蘭縣' aqi=49 status='良好' pm25=5.0 so2=0.3 co=0.28
# site_name='陽明' county='臺北市' aqi=51 status='普通' pm25=1.0 so2=0.8 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=61 status='普通' pm25=16.0 so2=0.8 co=0.24
# site_name='臺東' county='臺東縣' aqi=45 status='良好' pm25=0.0 so2=0.2 co=0.27
# site_name='恆春' county='屏東縣' aqi=48 status='良好' pm25=6.0 so2=0.6 co=0.15
# site_name='潮州' county='屏東縣' aqi=84 status='普通' pm25=14.0 so2=2.1 co=0.43
# site_name='屏東' county='屏東縣' aqi=104 status='對敏感族群不健康' pm25=13.0 so2=2.1 co=0.31
# site_name='小港' county='高雄市' aqi=48 status='良好' pm25=10.0 so2=1.4 co=0.28
# site_name='前鎮' county='高雄市' aqi=49 status='良好' pm25=7.0 so2=1.3 co=0.34
# site_name='前金' county='高雄市' aqi=58 status='普通' pm25=6.0 so2=0.6 co=0.26
# site_name='左營' county='高雄市' aqi=64 status='普通' pm25=13.0 so2=0.9 co=0.21
# site_name='楠梓' county='高雄市' aqi=67 status='普通' pm25=7.0 so2=1.1 co=0.25
# site_name='林園' county='高雄市' aqi=71 status='普通' pm25=12.0 so2=1.7 co=0.21
# site_name='大寮' county='高雄市' aqi=55 status='普通' pm25=12.0 so2=1.2 co=0.35
# site_name='鳳山' county='高雄市' aqi=51 status='普通' pm25=11.0 so2=1.1 co=0.86
# site_name='仁武' county='高雄市' aqi=77 status='普通' pm25=9.0 so2=0.7 co=0.25
# site_name='橋頭' county='高雄市' aqi=61 status='普通' pm25=9.0 so2=1.0 co=0.27
# site_name='美濃' county='高雄市' aqi=58 status='普通' pm25=4.0 so2=1.0 co=0.21
# site_name='臺南' county='臺南市' aqi=58 status='普通' pm25=14.0 so2=0.5 co=0.27
# site_name='安南' county='臺南市' aqi=51 status='普通' pm25=11.0 so2=0.4 co=0.23
# site_name='善化' county='臺南市' aqi=50 status='良好' pm25=11.0 so2=0.8 co=0.17
# site_name='新營' county='臺南市' aqi=54 status='普通' pm25=11.0 so2=1.6 co=0.23
# site_name='嘉義' county='嘉義市' aqi=64 status='普通' pm25=10.0 so2=1.9 co=0.3
# site_name='臺西' county='雲林縣' aqi=80 status='普通' pm25=19.0 so2=1.4 co=0.19
# site_name='朴子' county='嘉義縣' aqi=54 status='普通' pm25=0.0 so2=1.2 co=0.22
# site_name='新港' county='嘉義縣' aqi=67 status='普通' pm25=19.0 so2=1.8 co=0.19
# site_name='崙背' county='雲林縣' aqi=54 status='普通' pm25=17.0 so2=1.8 co=0.2
# site_name='斗六' county='雲林縣' aqi=74 status='普通' pm25=19.0 so2=3.7 co=0.41
# site_name='南投' county='南投縣' aqi=77 status='普通' pm25=13.0 so2=0.8 co=0.33
# site_name='二林' county='彰化縣' aqi=64 status='普通' pm25=26.0 so2=3.3 co=0.32
# site_name='線西' county='彰化縣' aqi=54 status='普通' pm25=21.0 so2=3.2 co=0.42
# site_name='彰化' county='彰化縣' aqi=71 status='普通' pm25=23.0 so2=1.0 co=0.32
# site_name='西屯' county='臺中市' aqi=49 status='良好' pm25=18.0 so2=1.0 co=0.28
# site_name='忠明' county='臺中市' aqi=67 status='普通' pm25=16.0 so2=1.2 co=0.35
# site_name='大里' county='臺中市' aqi=61 status='普通' pm25=14.0 so2=1.6 co=0.43
# site_name='沙鹿' county='臺中市' aqi=77 status='普通' pm25=21.0 so2=1.6 co=0.25
# site_name='豐原' county='臺中市' aqi=54 status='普通' pm25=23.0 so2=2.7 co=0.35
# site_name='三義' county='苗栗縣' aqi=58 status='普通' pm25=21.0 so2=1.5 co=0.29
# site_name='苗栗' county='苗栗縣' aqi=64 status='普通' pm25=18.0 so2=3.7 co=0.27
# site_name='頭份' county='苗栗縣' aqi=58 status='普通' pm25=16.0 so2=2.0 co=0.28
# site_name='新竹' county='新竹市' aqi=51 status='普通' pm25=9.0 so2=1.2 co=0.34
# site_name='竹東' county='新竹縣' aqi=48 status='良好' pm25=13.0 so2=0.3 co=0.24
# site_name='湖口' county='新竹縣' aqi=53 status='普通' pm25=14.0 so2=2.1 co=0.27
# site_name='龍潭' county='桃園市' aqi=44 status='良好' pm25=15.0 so2=1.1 co=0.29
# site_name='平鎮' county='桃園市' aqi=42 status='良好' pm25=10.0 so2=1.6 co=0.43
# site_name='觀音' county='桃園市' aqi=49 status='良好' pm25=19.0 so2=1.2 co=0.14
# site_name='大園' county='桃園市' aqi=43 status='良好' pm25=7.0 so2=1.9 co=0.2
# site_name='桃園' county='桃園市' aqi=45 status='良好' pm25=9.0 so2=1.3 co=0.39
# site_name='大同' county='臺北市' aqi=47 status='良好' pm25=12.0 so2=1.5 co=0.72
# site_name='松山' county='臺北市' aqi=49 status='良好' pm25=14.0 so2=1.6 co=0.26
# site_name='古亭' county='臺北市' aqi=43 status='良好' pm25=10.0 so2=0.0 co=0.29
# site_name='萬華' county='臺北市' aqi=44 status='良好' pm25=7.0 so2=1.9 co=0.31
# site_name='中山' county='臺北市' aqi=43 status='良好' pm25=12.0 so2=1.6 co=0.42
# site_name='士林' county='臺北市' aqi=46 status='良好' pm25=12.0 so2=0.5 co=0.2
# site_name='淡水' county='新北市' aqi=45 status='良好' pm25=13.0 so2=1.5 co=0.23
# site_name='林口' county='新北市' aqi=44 status='良好' pm25=10.0 so2=0.5 co=0.24
# site_name='菜寮' county='新北市' aqi=46 status='良好' pm25=12.0 so2=1.3 co=0.3
# site_name='新莊' county='新北市' aqi=47 status='良好' pm25=15.0 so2=1.4 co=0.24
# site_name='板橋' county='新北市' aqi=44 status='良好' pm25=7.0 so2=1.2 co=0.38
# site_name='土城' county='新北市' aqi=52 status='普通' pm25=18.0 so2=1.3 co=0.33
# site_name='新店' county='新北市' aqi=45 status='良好' pm25=16.0 so2=1.6 co=0.3
# site_name='萬里' county='新北市' aqi=67 status='普通' pm25=9.0 so2=0.9 co=0.14
# site_name='汐止' county='新北市' aqi=48 status='良好' pm25=14.0 so2=0.6 co=0.18
# site_name='基隆' county='基隆市' aqi=49 status='良好' pm25=7.0 so2=1.2 co=0.22
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=7.0 so2=0.4 co=0.13
# site_name='大甲（日南國小）' county='臺中市' aqi=46 status='良好' pm25=19.0 so2=0.8 co=0.19
# site_name='新北(樹林)' county='新北市' aqi=52 status='普通' pm25=16.0 so2=0.2 co=0.26
# site_name='屏東（琉球）' county='屏東縣' aqi=74 status='普通' pm25=17.0 so2=0.8 co=0.21
# site_name='臺南（麻豆）' county='臺南市' aqi=44 status='良好' pm25=9.0 so2=0.3 co=0.17
# site_name='高雄（湖內）' county='高雄市' aqi=43 status='良好' pm25=11.0 so2=0.6 co=0.18
# site_name='彰化（員林）' county='彰化縣' aqi=54 status='普通' pm25=15.0 so2=1.5 co=0.31
# site_name='大城' county='彰化縣' aqi=87 status='普通' pm25=16.0 so2=1.3 co=0.14
# site_name='富貴角' county='新北市' aqi=74 status='普通' pm25=14.0 so2=0.1 co=0.12
# site_name='麥寮' county='雲林縣' aqi=61 status='普通' pm25=13.0 so2=1.5 co=0.19
# site_name='關山' county='臺東縣' aqi=40 status='良好' pm25=11.0 so2=1.0 co=0.19
# site_name='馬公' county='澎湖縣' aqi=64 status='普通' pm25=9.0 so2=0.8 co=0.16
# site_name='金門' county='金門縣' aqi=126 status='對敏感族群不健康' pm25=13.0 so2=1.9 co=0.23
# site_name='馬祖' county='連江縣' aqi=90 status='普通' pm25=11.0 so2=0.8 co=0.15
# site_name='埔里' county='南投縣' aqi=30 status='良好' pm25=10.0 so2=0.9 co=0.29
# site_name='復興' county='高雄市' aqi=46 status='良好' pm25=7.0 so2=0.8 co=0.41
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=18.0 so2=1.3 co=0.33
# site_name='竹山' county='南投縣' aqi=47 status='良好' pm25=21.0 so2=1.3 co=0.2
# site_name='中壢' county='桃園市' aqi=51 status='普通' pm25=18.0 so2=1.3 co=0.8
# site_name='三重' county='新北市' aqi=48 status='良好' pm25=15.0 so2=1.7 co=0.84
# site_name='冬山' county='宜蘭縣' aqi=44 status='良好' pm25=12.0 so2=0.6 co=0.19
# site_name='宜蘭' county='宜蘭縣' aqi=50 status='良好' pm25=0.0 so2=0.3 co=0.26
# site_name='陽明' county='臺北市' aqi=54 status='普通' pm25=0.0 so2=0.8 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=61 status='普通' pm25=13.0 so2=0.7 co=0.21
# site_name='臺東' county='臺東縣' aqi=45 status='良好' pm25=10.0 so2=0.0 co=0.2
# site_name='恆春' county='屏東縣' aqi=49 status='良好' pm25=8.0 so2=0.7 co=0.15
# site_name='潮州' county='屏東縣' aqi=74 status='普通' pm25=11.0 so2=1.8 co=0.37
# site_name='屏東' county='屏東縣' aqi=97 status='普通' pm25=13.0 so2=2.1 co=0.3
# site_name='小港' county='高雄市' aqi=47 status='良好' pm25=13.0 so2=1.4 co=0.25
# site_name='前鎮' county='高雄市' aqi=47 status='良好' pm25=8.0 so2=1.3 co=0.27
# site_name='前金' county='高雄市' aqi=50 status='良好' pm25=8.0 so2=0.6 co=0.23
# site_name='左營' county='高雄市' aqi=54 status='普通' pm25=10.0 so2=0.9 co=0.19
# site_name='楠梓' county='高雄市' aqi=58 status='普通' pm25=12.0 so2=1.1 co=0.22
# site_name='林園' county='高雄市' aqi=67 status='普通' pm25=11.0 so2=1.5 co=0.24
# site_name='大寮' county='高雄市' aqi=58 status='普通' pm25=20.0 so2=1.9 co=0.27
# site_name='鳳山' county='高雄市' aqi=50 status='良好' pm25=8.0 so2=1.4 co=0.72
# site_name='仁武' county='高雄市' aqi=64 status='普通' pm25=7.0 so2=0.8 co=0.21
# site_name='橋頭' county='高雄市' aqi=51 status='普通' pm25=10.0 so2=1.2 co=0.23
# site_name='美濃' county='高雄市' aqi=50 status='良好' pm25=8.0 so2=1.1 co=0.27
# site_name='臺南' county='臺南市' aqi=51 status='普通' pm25=10.0 so2=0.6 co=0.21
# site_name='安南' county='臺南市' aqi=47 status='良好' pm25=6.0 so2=0.4 co=0.21
# site_name='善化' county='臺南市' aqi=51 status='普通' pm25=11.0 so2=0.9 co=0.15
# site_name='新營' county='臺南市' aqi=47 status='良好' pm25=9.0 so2=2.2 co=0.22
# site_name='嘉義' county='嘉義市' aqi=53 status='普通' pm25=11.0 so2=1.7 co=0.23
# site_name='臺西' county='雲林縣' aqi=67 status='普通' pm25=15.0 so2=1.4 co=0.18
# site_name='朴子' county='嘉義縣' aqi=48 status='良好' pm25=0.0 so2=1.4 co=0.2
# site_name='新港' county='嘉義縣' aqi=58 status='普通' pm25=14.0 so2=2.1 co=0.18
# site_name='崙背' county='雲林縣' aqi=54 status='普通' pm25=19.0 so2=1.7 co=0.19
# site_name='斗六' county='雲林縣' aqi=54 status='普通' pm25=16.0 so2=4.5 co=0.36
# site_name='南投' county='南投縣' aqi=58 status='普通' pm25=12.0 so2=0.8 co=0.28
# site_name='二林' county='彰化縣' aqi=61 status='普通' pm25=25.0 so2=3.6 co=0.28
# site_name='線西' county='彰化縣' aqi=55 status='普通' pm25=22.0 so2=5.8 co=0.56
# site_name='彰化' county='彰化縣' aqi=58 status='普通' pm25=18.0 so2=1.0 co=0.28
# site_name='西屯' county='臺中市' aqi=48 status='良好' pm25=15.0 so2=1.0 co=0.21
# site_name='忠明' county='臺中市' aqi=49 status='良好' pm25=16.0 so2=1.2 co=0.26
# site_name='大里' county='臺中市' aqi=49 status='良好' pm25=12.0 so2=1.6 co=0.27
# site_name='沙鹿' county='臺中市' aqi=67 status='普通' pm25=20.0 so2=1.6 co=0.23
# site_name='豐原' county='臺中市' aqi=46 status='良好' pm25=11.0 so2=1.3 co=0.23
# site_name='三義' county='苗栗縣' aqi=48 status='良好' pm25=20.0 so2=1.4 co=0.25
# site_name='苗栗' county='苗栗縣' aqi=64 status='普通' pm25=16.0 so2=2.1 co=0.23
# site_name='頭份' county='苗栗縣' aqi=58 status='普通' pm25=18.0 so2=2.2 co=0.24
# site_name='新竹' county='新竹市' aqi=58 status='普通' pm25=13.0 so2=1.5 co=0.29
# site_name='竹東' county='新竹縣' aqi=50 status='良好' pm25=14.0 so2=0.3 co=0.21
# site_name='湖口' county='新竹縣' aqi=52 status='普通' pm25=14.0 so2=1.9 co=0.23
# site_name='龍潭' county='桃園市' aqi=46 status='良好' pm25=11.0 so2=1.1 co=0.27
# site_name='平鎮' county='桃園市' aqi=44 status='良好' pm25=11.0 so2=1.5 co=0.38
# site_name='觀音' county='桃園市' aqi=50 status='良好' pm25=18.0 so2=0.6 co=0.13
# site_name='大園' county='桃園市' aqi=44 status='良好' pm25=9.0 so2=1.7 co=0.18
# site_name='桃園' county='桃園市' aqi=47 status='良好' pm25=10.0 so2=1.0 co=0.3
# site_name='大同' county='臺北市' aqi=49 status='良好' pm25=19.0 so2=1.8 co=0.52
# site_name='松山' county='臺北市' aqi=49 status='良好' pm25=16.0 so2=1.4 co=0.2
# site_name='古亭' county='臺北市' aqi=44 status='良好' pm25=13.0 so2=0.0 co=0.22
# site_name='萬華' county='臺北市' aqi=48 status='良好' pm25=17.0 so2=1.6 co=0.25
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=13.0 so2=2.0 co=0.31
# site_name='士林' county='臺北市' aqi=47 status='良好' pm25=12.0 so2=0.7 co=0.19
# site_name='淡水' county='新北市' aqi=47 status='良好' pm25=13.0 so2=1.6 co=0.25
# site_name='林口' county='新北市' aqi=44 status='良好' pm25=10.0 so2=0.6 co=0.22
# site_name='菜寮' county='新北市' aqi=48 status='良好' pm25=13.0 so2=1.5 co=0.27
# site_name='新莊' county='新北市' aqi=49 status='良好' pm25=15.0 so2=1.0 co=0.18
# site_name='板橋' county='新北市' aqi=45 status='良好' pm25=7.0 so2=1.0 co=0.3
# site_name='土城' county='新北市' aqi=53 status='普通' pm25=0.0 so2=1.2 co=0.28
# site_name='新店' county='新北市' aqi=47 status='良好' pm25=12.0 so2=1.7 co=0.27
# site_name='萬里' county='新北市' aqi=74 status='普通' pm25=7.0 so2=1.0 co=0.14
# site_name='汐止' county='新北市' aqi=50 status='良好' pm25=12.0 so2=0.7 co=0.16
# site_name='基隆' county='基隆市' aqi=51 status='普通' pm25=10.0 so2=1.1 co=0.2
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=3.0 so2=0.3 co=0.14
# site_name='大甲（日南國小）' county='臺中市' aqi=44 status='良好' pm25=15.0 so2=0.5 co=0.17
# site_name='新北(樹林)' county='新北市' aqi=50 status='良好' pm25=16.0 so2=0.4 co=0.26
# site_name='屏東（琉球）' county='屏東縣' aqi=61 status='普通' pm25=17.0 so2=0.6 co=0.22
# site_name='臺南（麻豆）' county='臺南市' aqi=41 status='良好' pm25=11.0 so2=0.6 co=0.17
# site_name='高雄（湖內）' county='高雄市' aqi=46 status='良好' pm25=9.0 so2=0.6 co=0.17
# site_name='彰化（員林）' county='彰化縣' aqi=53 status='普通' pm25=21.0 so2=1.4 co=0.25
# site_name='大城' county='彰化縣' aqi=71 status='普通' pm25=11.0 so2=1.1 co=0.14
# site_name='富貴角' county='新北市' aqi=80 status='普通' pm25=9.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=48 status='良好' pm25=16.0 so2=1.7 co=0.18
# site_name='關山' county='臺東縣' aqi=41 status='良好' pm25=7.0 so2=1.1 co=0.18
# site_name='馬公' county='澎湖縣' aqi=64 status='普通' pm25=7.0 so2=0.8 co=0.15
# site_name='金門' county='金門縣' aqi=122 status='對敏感族群不健康' pm25=19.0 so2=2.2 co=0.22
# site_name='馬祖' county='連江縣' aqi=90 status='普通' pm25=14.0 so2=0.8 co=0.15
# site_name='埔里' county='南投縣' aqi=29 status='良好' pm25=5.0 so2=0.9 co=0.22
# site_name='復興' county='高雄市' aqi=44 status='良好' pm25=9.0 so2=1.1 co=0.33
# site_name='永和' county='新北市' aqi=47 status='良好' pm25=14.0 so2=1.3 co=0.32
# site_name='竹山' county='南投縣' aqi=39 status='良好' pm25=14.0 so2=1.2 co=0.22
# site_name='中壢' county='桃園市' aqi=50 status='良好' pm25=18.0 so2=2.2 co=0.8
# site_name='三重' county='新北市' aqi=44 status='良好' pm25=15.0 so2=1.5 co=0.8
# site_name='冬山' county='宜蘭縣' aqi=45 status='良好' pm25=8.0 so2=1.0 co=0.17
# site_name='宜蘭' county='宜蘭縣' aqi=49 status='良好' pm25=0.0 so2=0.4 co=0.18
# site_name='陽明' county='臺北市' aqi=61 status='普通' pm25=1.0 so2=0.8 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=61 status='普通' pm25=13.0 so2=0.7 co=0.2
# site_name='臺東' county='臺東縣' aqi=45 status='良好' pm25=12.0 so2=1.1 co=0.25
# site_name='恆春' county='屏東縣' aqi=49 status='良好' pm25=8.0 so2=0.7 co=0.15
# site_name='潮州' county='屏東縣' aqi=58 status='普通' pm25=15.0 so2=0.9 co=0.25
# site_name='屏東' county='屏東縣' aqi=84 status='普通' pm25=9.0 so2=2.0 co=0.32
# site_name='小港' county='高雄市' aqi=47 status='良好' pm25=14.0 so2=1.8 co=0.26
# site_name='前鎮' county='高雄市' aqi=44 status='良好' pm25=11.0 so2=2.3 co=0.24
# site_name='前金' county='高雄市' aqi=47 status='良好' pm25=9.0 so2=0.9 co=0.25
# site_name='左營' county='高雄市' aqi=52 status='普通' pm25=10.0 so2=0.7 co=0.2
# site_name='楠梓' county='高雄市' aqi=57 status='普通' pm25=11.0 so2=1.0 co=0.19
# site_name='林園' county='高雄市' aqi=54 status='普通' pm25=11.0 so2=1.9 co=0.24
# site_name='大寮' county='高雄市' aqi=58 status='普通' pm25=19.0 so2=4.4 co=0.38
# site_name='鳳山' county='高雄市' aqi=47 status='良好' pm25=10.0 so2=1.5 co=0.73
# site_name='仁武' county='高雄市' aqi=51 status='普通' pm25=10.0 so2=0.0 co=0.2
# site_name='橋頭' county='高雄市' aqi=57 status='普通' pm25=9.0 so2=1.1 co=0.18
# site_name='美濃' county='高雄市' aqi=44 status='良好' pm25=8.0 so2=1.0 co=0.25
# site_name='臺南' county='臺南市' aqi=52 status='普通' pm25=10.0 so2=0.9 co=0.21
# site_name='安南' county='臺南市' aqi=44 status='良好' pm25=8.0 so2=0.7 co=0.2
# site_name='善化' county='臺南市' aqi=52 status='普通' pm25=13.0 so2=0.9 co=0.15
# site_name='新營' county='臺南市' aqi=41 status='良好' pm25=11.0 so2=2.3 co=0.25
# site_name='嘉義' county='嘉義市' aqi=58 status='普通' pm25=13.0 so2=2.3 co=0.23
# site_name='臺西' county='雲林縣' aqi=51 status='普通' pm25=10.0 so2=1.6 co=0.17
# site_name='朴子' county='嘉義縣' aqi=44 status='良好' pm25=0.0 so2=1.8 co=0.22
# site_name='新港' county='嘉義縣' aqi=62 status='普通' pm25=14.0 so2=2.3 co=0.17
# site_name='崙背' county='雲林縣' aqi=54 status='普通' pm25=14.0 so2=1.6 co=0.18
# site_name='斗六' county='雲林縣' aqi=53 status='普通' pm25=23.0 so2=4.3 co=0.35
# site_name='南投' county='南投縣' aqi=44 status='良好' pm25=15.0 so2=0.7 co=0.27
# site_name='二林' county='彰化縣' aqi=55 status='普通' pm25=24.0 so2=0.0 co=0.27
# site_name='線西' county='彰化縣' aqi=51 status='普通' pm25=18.0 so2=5.4 co=0.5
# site_name='彰化' county='彰化縣' aqi=47 status='良好' pm25=14.0 so2=0.9 co=0.23
# site_name='西屯' county='臺中市' aqi=47 status='良好' pm25=15.0 so2=1.0 co=0.2
# site_name='忠明' county='臺中市' aqi=42 status='良好' pm25=17.0 so2=1.3 co=0.25
# site_name='大里' county='臺中市' aqi=43 status='良好' pm25=14.0 so2=1.6 co=0.26
# site_name='沙鹿' county='臺中市' aqi=54 status='普通' pm25=21.0 so2=1.5 co=0.21
# site_name='豐原' county='臺中市' aqi=41 status='良好' pm25=16.0 so2=1.4 co=0.24
# site_name='三義' county='苗栗縣' aqi=43 status='良好' pm25=19.0 so2=1.5 co=0.23
# site_name='苗栗' county='苗栗縣' aqi=58 status='普通' pm25=17.0 so2=1.9 co=0.22
# site_name='頭份' county='苗栗縣' aqi=51 status='普通' pm25=15.0 so2=2.9 co=0.24
# site_name='新竹' county='新竹市' aqi=58 status='普通' pm25=12.0 so2=1.5 co=0.27
# site_name='竹東' county='新竹縣' aqi=50 status='良好' pm25=16.0 so2=0.5 co=0.21
# site_name='湖口' county='新竹縣' aqi=53 status='普通' pm25=17.0 so2=1.9 co=0.21
# site_name='龍潭' county='桃園市' aqi=47 status='良好' pm25=13.0 so2=1.0 co=0.24
# site_name='平鎮' county='桃園市' aqi=47 status='良好' pm25=10.0 so2=1.6 co=0.31
# site_name='觀音' county='桃園市' aqi=54 status='普通' pm25=14.0 so2=0.5 co=0.14
# site_name='大園' county='桃園市' aqi=45 status='良好' pm25=11.0 so2=1.7 co=0.16
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=9.0 so2=1.2 co=0.28
# site_name='大同' county='臺北市' aqi=47 status='良好' pm25=10.0 so2=1.5 co=0.42
# site_name='松山' county='臺北市' aqi=48 status='良好' pm25=17.0 so2=1.4 co=0.19
# site_name='古亭' county='臺北市' aqi=43 status='良好' pm25=15.0 so2=0.0 co=0.23
# site_name='萬華' county='臺北市' aqi=47 status='良好' pm25=15.0 so2=1.4 co=0.25
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=11.0 so2=1.8 co=0.28
# site_name='士林' county='臺北市' aqi=49 status='良好' pm25=16.0 so2=0.6 co=0.18
# site_name='淡水' county='新北市' aqi=48 status='良好' pm25=8.0 so2=1.7 co=0.19
# site_name='林口' county='新北市' aqi=45 status='良好' pm25=8.0 so2=0.4 co=0.2
# site_name='菜寮' county='新北市' aqi=50 status='良好' pm25=11.0 so2=1.6 co=0.23
# site_name='新莊' county='新北市' aqi=50 status='良好' pm25=15.0 so2=1.0 co=0.2
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=5.0 so2=1.3 co=0.28
# site_name='土城' county='新北市' aqi=54 status='普通' pm25=0.0 so2=1.3 co=0.25
# site_name='新店' county='新北市' aqi=48 status='良好' pm25=14.0 so2=1.6 co=0.23
# site_name='萬里' county='新北市' aqi=80 status='普通' pm25=10.0 so2=0.9 co=0.14
# site_name='汐止' county='新北市' aqi=51 status='普通' pm25=11.0 so2=0.6 co=0.15
# site_name='基隆' county='基隆市' aqi=58 status='普通' pm25=11.0 so2=1.1 co=0.19
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=2.0 so2=0.3 co=0.13
# site_name='大甲（日南國小）' county='臺中市' aqi=39 status='良好' pm25=15.0 so2=0.6 co=0.13
# site_name='新北(樹林)' county='新北市' aqi=49 status='良好' pm25=16.0 so2=0.3 co=0.25
# site_name='屏東（琉球）' county='屏東縣' aqi=57 status='普通' pm25=18.0 so2=0.7 co=0.22
# site_name='臺南（麻豆）' county='臺南市' aqi=44 status='良好' pm25=11.0 so2=0.5 co=0.18
# site_name='高雄（湖內）' county='高雄市' aqi=53 status='普通' pm25=6.0 so2=0.5 co=0.17
# site_name='彰化（員林）' county='彰化縣' aqi=53 status='普通' pm25=21.0 so2=1.6 co=0.29
# site_name='大城' county='彰化縣' aqi=54 status='普通' pm25=10.0 so2=1.3 co=0.15
# site_name='富貴角' county='新北市' aqi=84 status='普通' pm25=9.0 so2=0.2 co=0.13
# site_name='麥寮' county='雲林縣' aqi=44 status='良好' pm25=13.0 so2=1.6 co=0.19
# site_name='關山' county='臺東縣' aqi=42 status='良好' pm25=6.0 so2=1.3 co=0.17
# site_name='馬公' county='澎湖縣' aqi=67 status='普通' pm25=11.0 so2=0.8 co=0.16
# site_name='金門' county='金門縣' aqi=115 status='對敏感族群不健康' pm25=14.0 so2=2.3 co=0.24
# site_name='馬祖' county='連江縣' aqi=90 status='普通' pm25=11.0 so2=0.8 co=0.15
# site_name='埔里' county='南投縣' aqi=26 status='良好' pm25=5.0 so2=0.8 co=0.2
# site_name='復興' county='高雄市' aqi=40 status='良好' pm25=9.0 so2=1.0 co=0.32
# site_name='永和' county='新北市' aqi=47 status='良好' pm25=15.0 so2=1.3 co=0.3
# site_name='竹山' county='南投縣' aqi=36 status='良好' pm25=0.0 so2=1.0 co=0.17
# site_name='中壢' county='桃園市' aqi=45 status='良好' pm25=11.0 so2=0.0 co=0.56
# site_name='三重' county='新北市' aqi=44 status='良好' pm25=14.0 so2=1.2 co=0.69
# site_name='冬山' county='宜蘭縣' aqi=43 status='良好' pm25=10.0 so2=0.8 co=0.17
# site_name='宜蘭' county='宜蘭縣' aqi=48 status='良好' pm25=0.0 so2=0.6 co=0.17
# site_name='陽明' county='臺北市' aqi=67 status='普通' pm25=4.0 so2=0.9 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=54 status='普通' pm25=8.0 so2=0.8 co=0.21
# site_name='臺東' county='臺東縣' aqi=45 status='良好' pm25=5.0 so2=0.8 co=0.2
# site_name='恆春' county='屏東縣' aqi=49 status='良好' pm25=11.0 so2=0.6 co=0.15
# site_name='潮州' county='屏東縣' aqi=46 status='良好' pm25=12.0 so2=0.7 co=0.19
# site_name='屏東' county='屏東縣' aqi=61 status='普通' pm25=15.0 so2=1.4 co=0.32
# site_name='小港' county='高雄市' aqi=47 status='良好' pm25=17.0 so2=2.0 co=0.26
# site_name='前鎮' county='高雄市' aqi=41 status='良好' pm25=7.0 so2=1.8 co=0.24
# site_name='前金' county='高雄市' aqi=43 status='良好' pm25=6.0 so2=0.7 co=0.23
# site_name='左營' county='高雄市' aqi=57 status='普通' pm25=12.0 so2=0.7 co=0.2
# site_name='楠梓' county='高雄市' aqi=62 status='普通' pm25=20.0 so2=1.8 co=0.23
# site_name='林園' county='高雄市' aqi=47 status='良好' pm25=0.0 so2=1.9 co=0.24
# site_name='大寮' county='高雄市' aqi=62 status='普通' pm25=17.0 so2=6.0 co=0.43
# site_name='鳳山' county='高雄市' aqi=44 status='良好' pm25=7.0 so2=2.3 co=0.53
# site_name='仁武' county='高雄市' aqi=55 status='普通' pm25=13.0 so2=0.8 co=0.22
# site_name='橋頭' county='高雄市' aqi=66 status='普通' pm25=8.0 so2=1.4 co=0.21
# site_name='美濃' county='高雄市' aqi=38 status='良好' pm25=18.0 so2=0.8 co=0.28
# site_name='臺南' county='臺南市' aqi=55 status='普通' pm25=9.0 so2=0.8 co=0.19
# site_name='安南' county='臺南市' aqi=42 status='良好' pm25=7.0 so2=0.6 co=0.19
# site_name='善化' county='臺南市' aqi=54 status='普通' pm25=17.0 so2=0.8 co=0.18
# site_name='新營' county='臺南市' aqi=40 status='良好' pm25=8.0 so2=1.4 co=0.22
# site_name='嘉義' county='嘉義市' aqi=60 status='普通' pm25=16.0 so2=1.9 co=0.28
# site_name='臺西' county='雲林縣' aqi=47 status='良好' pm25=15.0 so2=2.3 co=0.2
# site_name='朴子' county='嘉義縣' aqi=39 status='良好' pm25=0.0 so2=1.5 co=0.21
# site_name='新港' county='嘉義縣' aqi=64 status='普通' pm25=22.0 so2=2.6 co=0.19
# site_name='崙背' county='雲林縣' aqi=54 status='普通' pm25=19.0 so2=1.8 co=0.19
# site_name='斗六' county='雲林縣' aqi=49 status='良好' pm25=18.0 so2=1.7 co=0.29
# site_name='南投' county='南投縣' aqi=36 status='良好' pm25=7.0 so2=0.6 co=0.23
# site_name='二林' county='彰化縣' aqi=50 status='良好' pm25=22.0 so2=0.0 co=0.27
# site_name='線西' county='彰化縣' aqi=46 status='良好' pm25=13.0 so2=5.8 co=0.44
# site_name='彰化' county='彰化縣' aqi=41 status='良好' pm25=14.0 so2=0.8 co=0.24
# site_name='西屯' county='臺中市' aqi=44 status='良好' pm25=16.0 so2=1.1 co=0.22
# site_name='忠明' county='臺中市' aqi=34 status='良好' pm25=13.0 so2=1.2 co=0.26
# site_name='大里' county='臺中市' aqi=35 status='良好' pm25=7.0 so2=1.4 co=0.27
# site_name='沙鹿' county='臺中市' aqi=46 status='良好' pm25=15.0 so2=1.5 co=0.21
# site_name='豐原' county='臺中市' aqi=36 status='良好' pm25=15.0 so2=2.6 co=0.29
# site_name='三義' county='苗栗縣' aqi=38 status='良好' pm25=13.0 so2=1.3 co=0.24
# site_name='苗栗' county='苗栗縣' aqi=50 status='良好' pm25=16.0 so2=1.6 co=0.16
# site_name='頭份' county='苗栗縣' aqi=51 status='普通' pm25=17.0 so2=3.2 co=0.21
# site_name='新竹' county='新竹市' aqi=58 status='普通' pm25=11.0 so2=1.6 co=0.24
# site_name='竹東' county='新竹縣' aqi=49 status='良好' pm25=16.0 so2=0.5 co=0.21
# site_name='湖口' county='新竹縣' aqi=53 status='普通' pm25=21.0 so2=1.8 co=0.18
# site_name='龍潭' county='桃園市' aqi=47 status='良好' pm25=13.0 so2=1.0 co=0.23
# site_name='平鎮' county='桃園市' aqi=48 status='良好' pm25=8.0 so2=1.6 co=0.27
# site_name='觀音' county='桃園市' aqi=54 status='普通' pm25=0.0 so2=0.6 co=0.13
# site_name='大園' county='桃園市' aqi=46 status='良好' pm25=11.0 so2=1.8 co=0.16
# site_name='桃園' county='桃園市' aqi=49 status='良好' pm25=11.0 so2=1.3 co=0.25
# site_name='大同' county='臺北市' aqi=52 status='普通' pm25=17.0 so2=1.5 co=0.48
# site_name='松山' county='臺北市' aqi=45 status='良好' pm25=14.0 so2=1.7 co=0.18
# site_name='古亭' county='臺北市' aqi=43 status='良好' pm25=15.0 so2=0.0 co=0.2
# site_name='萬華' county='臺北市' aqi=48 status='良好' pm25=0.0 so2=1.8 co=0.23
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=16.0 so2=1.9 co=0.27
# site_name='士林' county='臺北市' aqi=50 status='良好' pm25=15.0 so2=0.5 co=0.18
# site_name='淡水' county='新北市' aqi=49 status='良好' pm25=10.0 so2=1.5 co=0.22
# site_name='林口' county='新北市' aqi=46 status='良好' pm25=8.0 so2=0.5 co=0.19
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=10.0 so2=1.3 co=0.23
# site_name='新莊' county='新北市' aqi=51 status='普通' pm25=13.0 so2=0.9 co=0.17
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=15.0 so2=1.4 co=0.26
# site_name='土城' county='新北市' aqi=53 status='普通' pm25=13.0 so2=1.3 co=0.23
# site_name='新店' county='新北市' aqi=49 status='良好' pm25=12.0 so2=1.7 co=0.21
# site_name='萬里' county='新北市' aqi=87 status='普通' pm25=11.0 so2=0.9 co=0.15
# site_name='汐止' county='新北市' aqi=50 status='良好' pm25=13.0 so2=0.7 co=0.14
# site_name='基隆' county='基隆市' aqi=61 status='普通' pm25=9.0 so2=1.3 co=0.18
# site_name='屏東(枋山)' county='屏東縣' aqi=45 status='良好' pm25=2.0 so2=0.4 co=0.13
# site_name='大甲（日南國小）' county='臺中市' aqi=36 status='良好' pm25=18.0 so2=0.8 co=0.14
# site_name='新北(樹林)' county='新北市' aqi=49 status='良好' pm25=16.0 so2=0.2 co=0.24
# site_name='屏東（琉球）' county='屏東縣' aqi=58 status='普通' pm25=18.0 so2=0.8 co=0.24
# site_name='臺南（麻豆）' county='臺南市' aqi=46 status='良好' pm25=10.0 so2=0.3 co=0.21
# site_name='高雄（湖內）' county='高雄市' aqi=61 status='普通' pm25=6.0 so2=0.5 co=0.19
# site_name='彰化（員林）' county='彰化縣' aqi=48 status='良好' pm25=17.0 so2=1.6 co=0.32
# site_name='大城' county='彰化縣' aqi=46 status='良好' pm25=15.0 so2=1.1 co=0.17
# site_name='富貴角' county='新北市' aqi=90 status='普通' pm25=13.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=43 status='良好' pm25=15.0 so2=1.6 co=0.21
# site_name='關山' county='臺東縣' aqi=42 status='良好' pm25=8.0 so2=1.2 co=0.17
# site_name='馬公' county='澎湖縣' aqi=71 status='普通' pm25=9.0 so2=0.8 co=0.17
# site_name='金門' county='金門縣' aqi=104 status='對敏感族群不健康' pm25=12.0 so2=2.1 co=0.24
# site_name='馬祖' county='連江縣' aqi=90 status='普通' pm25=13.0 so2=1.0 co=0.16
# site_name='埔里' county='南投縣' aqi=21 status='良好' pm25=3.0 so2=0.6 co=0.14
# site_name='復興' county='高雄市' aqi=39 status='良好' pm25=11.0 so2=0.7 co=0.29
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=14.0 so2=1.2 co=0.31
# site_name='竹山' county='南投縣' aqi=40 status='良好' pm25=7.0 so2=0.9 co=0.15
# site_name='中壢' county='桃園市' aqi=46 status='良好' pm25=18.0 so2=2.0 co=0.62
# site_name='三重' county='新北市' aqi=45 status='良好' pm25=13.0 so2=1.3 co=0.61
# site_name='冬山' county='宜蘭縣' aqi=41 status='良好' pm25=10.0 so2=0.7 co=0.16
# site_name='宜蘭' county='宜蘭縣' aqi=45 status='良好' pm25=0.0 so2=0.7 co=0.16
# site_name='陽明' county='臺北市' aqi=71 status='普通' pm25=6.0 so2=0.7 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=50 status='良好' pm25=15.0 so2=0.9 co=0.23
# site_name='臺東' county='臺東縣' aqi=44 status='良好' pm25=4.0 so2=0.4 co=0.19
# site_name='恆春' county='屏東縣' aqi=49 status='良好' pm25=9.0 so2=0.6 co=0.16
# site_name='潮州' county='屏東縣' aqi=40 status='良好' pm25=15.0 so2=0.8 co=0.22
# site_name='屏東' county='屏東縣' aqi=45 status='良好' pm25=18.0 so2=1.4 co=0.4
# site_name='小港' county='高雄市' aqi=48 status='良好' pm25=9.0 so2=1.7 co=0.22
# site_name='前鎮' county='高雄市' aqi=38 status='良好' pm25=10.0 so2=1.5 co=0.23
# site_name='前金' county='高雄市' aqi=39 status='良好' pm25=7.0 so2=0.5 co=0.23
# site_name='左營' county='高雄市' aqi=63 status='普通' pm25=12.0 so2=0.9 co=0.2
# site_name='楠梓' county='高雄市' aqi=63 status='普通' pm25=10.0 so2=0.9 co=0.21
# site_name='林園' county='高雄市' aqi=42 status='良好' pm25=0.0 so2=1.7 co=0.23
# site_name='大寮' county='高雄市' aqi=63 status='普通' pm25=24.0 so2=13.3 co=0.77
# site_name='鳳山' county='高雄市' aqi=44 status='良好' pm25=9.0 so2=1.4 co=0.44
# site_name='仁武' county='高雄市' aqi=59 status='普通' pm25=15.0 so2=0.2 co=0.23
# site_name='橋頭' county='高雄市' aqi=73 status='普通' pm25=14.0 so2=1.1 co=0.2
# site_name='美濃' county='高雄市' aqi=30 status='良好' pm25=16.0 so2=0.6 co=0.24
# site_name='臺南' county='臺南市' aqi=60 status='普通' pm25=13.0 so2=0.7 co=0.23
# site_name='安南' county='臺南市' aqi=46 status='良好' pm25=11.0 so2=0.4 co=0.23
# site_name='善化' county='臺南市' aqi=56 status='普通' pm25=11.0 so2=0.7 co=0.19
# site_name='新營' county='臺南市' aqi=42 status='良好' pm25=14.0 so2=1.1 co=0.26
# site_name='嘉義' county='嘉義市' aqi=58 status='普通' pm25=15.0 so2=1.7 co=0.26
# site_name='臺西' county='雲林縣' aqi=42 status='良好' pm25=16.0 so2=2.4 co=0.22
# site_name='朴子' county='嘉義縣' aqi=33 status='良好' pm25=0.0 so2=1.3 co=0.21
# site_name='新港' county='嘉義縣' aqi=62 status='普通' pm25=24.0 so2=2.5 co=0.27
# site_name='崙背' county='雲林縣' aqi=54 status='普通' pm25=20.0 so2=2.9 co=0.24
# site_name='斗六' county='雲林縣' aqi=51 status='普通' pm25=14.0 so2=1.2 co=0.24
# site_name='南投' county='南投縣' aqi=35 status='良好' pm25=6.0 so2=0.4 co=0.23
# site_name='二林' county='彰化縣' aqi=46 status='良好' pm25=0.0 so2=3.8 co=0.3
# site_name='線西' county='彰化縣' aqi=41 status='良好' pm25=23.0 so2=3.4 co=0.28
# site_name='彰化' county='彰化縣' aqi=35 status='良好' pm25=10.0 so2=0.0 co=0.25
# site_name='西屯' county='臺中市' aqi=44 status='良好' pm25=18.0 so2=0.8 co=0.23
# site_name='忠明' county='臺中市' aqi=28 status='良好' pm25=9.0 so2=1.2 co=0.26
# site_name='大里' county='臺中市' aqi=39 status='良好' pm25=10.0 so2=1.5 co=0.34
# site_name='沙鹿' county='臺中市' aqi=42 status='良好' pm25=16.0 so2=1.5 co=0.25
# site_name='豐原' county='臺中市' aqi=34 status='良好' pm25=13.0 so2=2.5 co=0.27
# site_name='三義' county='苗栗縣' aqi=32 status='良好' pm25=10.0 so2=0.9 co=0.22
# site_name='苗栗' county='苗栗縣' aqi=49 status='良好' pm25=17.0 so2=2.3 co=0.17
# site_name='頭份' county='苗栗縣' aqi=48 status='良好' pm25=19.0 so2=2.5 co=0.24
# site_name='新竹' county='新竹市' aqi=54 status='普通' pm25=14.0 so2=1.7 co=0.24
# site_name='竹東' county='新竹縣' aqi=48 status='良好' pm25=20.0 so2=0.4 co=0.21
# site_name='湖口' county='新竹縣' aqi=51 status='普通' pm25=13.0 so2=1.7 co=0.16
# site_name='龍潭' county='桃園市' aqi=47 status='良好' pm25=17.0 so2=0.8 co=0.23
# site_name='平鎮' county='桃園市' aqi=48 status='良好' pm25=11.0 so2=1.5 co=0.27
# site_name='觀音' county='桃園市' aqi=54 status='普通' pm25=8.0 so2=0.7 co=0.13
# site_name='大園' county='桃園市' aqi=45 status='良好' pm25=6.0 so2=1.6 co=0.15
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=10.0 so2=1.4 co=0.24
# site_name='大同' county='臺北市' aqi=50 status='良好' pm25=14.0 so2=1.3 co=0.3
# site_name='松山' county='臺北市' aqi=48 status='良好' pm25=13.0 so2=1.1 co=0.18
# site_name='古亭' county='臺北市' aqi=44 status='良好' pm25=14.0 so2=0.0 co=0.21
# site_name='萬華' county='臺北市' aqi=49 status='良好' pm25=14.0 so2=2.5 co=0.24
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=12.0 so2=2.0 co=0.27
# site_name='士林' county='臺北市' aqi=54 status='普通' pm25=18.0 so2=0.4 co=0.18
# site_name='淡水' county='新北市' aqi=47 status='良好' pm25=13.0 so2=1.7 co=0.2
# site_name='林口' county='新北市' aqi=47 status='良好' pm25=11.0 so2=0.2 co=0.17
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=10.0 so2=1.0 co=0.22
# site_name='新莊' county='新北市' aqi=54 status='普通' pm25=13.0 so2=0.9 co=0.17
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=8.0 so2=1.7 co=0.26
# site_name='土城' county='新北市' aqi=55 status='普通' pm25=20.0 so2=1.3 co=0.22
# site_name='新店' county='新北市' aqi=50 status='良好' pm25=19.0 so2=1.8 co=0.2
# site_name='萬里' county='新北市' aqi=90 status='普通' pm25=7.0 so2=1.0 co=0.14
# site_name='汐止' county='新北市' aqi=49 status='良好' pm25=10.0 so2=0.7 co=0.15
# site_name='基隆' county='基隆市' aqi=67 status='普通' pm25=11.0 so2=1.2 co=0.19
# site_name='屏東(枋山)' county='屏東縣' aqi=45 status='良好' pm25=2.0 so2=0.3 co=0.13
# site_name='大甲（日南國小）' county='臺中市' aqi=36 status='良好' pm25=10.0 so2=0.8 co=0.0
# site_name='新北(樹林)' county='新北市' aqi=48 status='良好' pm25=12.0 so2=0.3 co=0.26
# site_name='屏東（琉球）' county='屏東縣' aqi=57 status='普通' pm25=21.0 so2=1.0 co=0.26
# site_name='臺南（麻豆）' county='臺南市' aqi=51 status='普通' pm25=10.0 so2=0.5 co=0.22
# site_name='高雄（湖內）' county='高雄市' aqi=71 status='普通' pm25=15.0 so2=0.4 co=0.23
# site_name='彰化（員林）' county='彰化縣' aqi=46 status='良好' pm25=14.0 so2=1.7 co=0.35
# site_name='大城' county='彰化縣' aqi=41 status='良好' pm25=11.0 so2=1.2 co=0.18
# site_name='富貴角' county='新北市' aqi=93 status='普通' pm25=12.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=41 status='良好' pm25=11.0 so2=2.1 co=0.2
# site_name='關山' county='臺東縣' aqi=42 status='良好' pm25=3.0 so2=1.2 co=0.17
# site_name='馬公' county='澎湖縣' aqi=71 status='普通' pm25=8.0 so2=0.9 co=0.18
# site_name='金門' county='金門縣' aqi=97 status='普通' pm25=13.0 so2=1.9 co=0.25
# site_name='馬祖' county='連江縣' aqi=87 status='普通' pm25=12.0 so2=1.0 co=0.17
# site_name='埔里' county='南投縣' aqi=20 status='良好' pm25=4.0 so2=0.7 co=0.16
# site_name='復興' county='高雄市' aqi=40 status='良好' pm25=16.0 so2=1.0 co=0.35
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=17.0 so2=1.3 co=0.28
# site_name='竹山' county='南投縣' aqi=46 status='良好' pm25=10.0 so2=0.8 co=0.16
# site_name='中壢' county='桃園市' aqi=45 status='良好' pm25=13.0 so2=1.6 co=0.69
# site_name='三重' county='新北市' aqi=45 status='良好' pm25=15.0 so2=1.5 co=0.6
# site_name='冬山' county='宜蘭縣' aqi=38 status='良好' pm25=8.0 so2=0.6 co=0.17
# site_name='宜蘭' county='宜蘭縣' aqi=44 status='良好' pm25=11.0 so2=0.9 co=0.21
# site_name='陽明' county='臺北市' aqi=74 status='普通' pm25=6.0 so2=0.8 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=47 status='良好' pm25=11.0 so2=1.0 co=0.24
# site_name='臺東' county='臺東縣' aqi=44 status='良好' pm25=9.0 so2=0.4 co=0.2
# site_name='恆春' county='屏東縣' aqi=50 status='良好' pm25=12.0 so2=0.6 co=0.16
# site_name='潮州' county='屏東縣' aqi=32 status='良好' pm25=14.0 so2=1.2 co=0.25
# site_name='屏東' county='屏東縣' aqi=36 status='良好' pm25=21.0 so2=1.4 co=0.42
# site_name='小港' county='高雄市' aqi=55 status='普通' pm25=0.0 so2=1.6 co=0.25
# site_name='前鎮' county='高雄市' aqi=39 status='良好' pm25=10.0 so2=2.3 co=0.26
# site_name='前金' county='高雄市' aqi=35 status='良好' pm25=6.0 so2=0.4 co=0.21
# site_name='左營' county='高雄市' aqi=68 status='普通' pm25=21.0 so2=0.9 co=0.25
# site_name='楠梓' county='高雄市' aqi=66 status='普通' pm25=24.0 so2=1.0 co=0.29
# site_name='林園' county='高雄市' aqi=35 status='良好' pm25=0.0 so2=1.8 co=0.25
# site_name='大寮' county='高雄市' aqi=56 status='普通' pm25=23.0 so2=14.1 co=0.84
# site_name='鳳山' county='高雄市' aqi=48 status='良好' pm25=9.0 so2=1.2 co=0.51
# site_name='仁武' county='高雄市' aqi=58 status='普通' pm25=24.0 so2=0.4 co=0.29
# site_name='橋頭' county='高雄市' aqi=78 status='普通' pm25=24.0 so2=1.2 co=0.27
# site_name='美濃' county='高雄市' aqi=23 status='良好' pm25=0.0 so2=0.7 co=0.21
# site_name='臺南' county='臺南市' aqi=66 status='普通' pm25=16.0 so2=0.5 co=0.26
# site_name='安南' county='臺南市' aqi=52 status='普通' pm25=11.0 so2=0.4 co=0.22
# site_name='善化' county='臺南市' aqi=61 status='普通' pm25=11.0 so2=0.9 co=0.17
# site_name='新營' county='臺南市' aqi=43 status='良好' pm25=13.0 so2=1.2 co=0.25
# site_name='嘉義' county='嘉義市' aqi=59 status='普通' pm25=23.0 so2=1.9 co=0.3
# site_name='臺西' county='雲林縣' aqi=39 status='良好' pm25=14.0 so2=1.6 co=0.2
# site_name='朴子' county='嘉義縣' aqi=30 status='良好' pm25=0.0 so2=1.4 co=0.23
# site_name='新港' county='嘉義縣' aqi=60 status='普通' pm25=23.0 so2=2.0 co=0.33
# site_name='崙背' county='雲林縣' aqi=52 status='普通' pm25=22.0 so2=2.3 co=0.34
# site_name='斗六' county='雲林縣' aqi=53 status='普通' pm25=12.0 so2=1.2 co=0.24
# site_name='南投' county='南投縣' aqi=36 status='良好' pm25=16.0 so2=0.4 co=0.3
# site_name='二林' county='彰化縣' aqi=44 status='良好' pm25=13.0 so2=2.8 co=0.44
# site_name='線西' county='彰化縣' aqi=33 status='良好' pm25=19.0 so2=5.5 co=0.39
# site_name='彰化' county='彰化縣' aqi=32 status='良好' pm25=14.0 so2=0.9 co=0.31
# site_name='西屯' county='臺中市' aqi=41 status='良好' pm25=14.0 so2=0.8 co=0.24
# site_name='忠明' county='臺中市' aqi=28 status='良好' pm25=11.0 so2=1.1 co=0.31
# site_name='大里' county='臺中市' aqi=41 status='良好' pm25=11.0 so2=1.5 co=0.44
# site_name='沙鹿' county='臺中市' aqi=37 status='良好' pm25=16.0 so2=1.2 co=0.25
# site_name='豐原' county='臺中市' aqi=31 status='良好' pm25=9.0 so2=1.2 co=0.32
# site_name='三義' county='苗栗縣' aqi=31 status='良好' pm25=8.0 so2=0.9 co=0.21
# site_name='苗栗' county='苗栗縣' aqi=46 status='良好' pm25=15.0 so2=1.6 co=0.25
# site_name='頭份' county='苗栗縣' aqi=47 status='良好' pm25=18.0 so2=1.9 co=0.23
# site_name='新竹' county='新竹市' aqi=51 status='普通' pm25=14.0 so2=1.5 co=0.28
# site_name='竹東' county='新竹縣' aqi=47 status='良好' pm25=17.0 so2=0.4 co=0.21
# site_name='湖口' county='新竹縣' aqi=53 status='普通' pm25=18.0 so2=2.1 co=0.2
# site_name='龍潭' county='桃園市' aqi=47 status='良好' pm25=20.0 so2=0.8 co=0.23
# site_name='平鎮' county='桃園市' aqi=47 status='良好' pm25=11.0 so2=1.1 co=0.32
# site_name='觀音' county='桃園市' aqi=58 status='普通' pm25=14.0 so2=0.7 co=0.13
# site_name='大園' county='桃園市' aqi=46 status='良好' pm25=15.0 so2=0.0 co=0.15
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=11.0 so2=0.9 co=0.27
# site_name='大同' county='臺北市' aqi=49 status='良好' pm25=17.0 so2=1.8 co=0.31
# site_name='松山' county='臺北市' aqi=48 status='良好' pm25=15.0 so2=1.3 co=0.18
# site_name='古亭' county='臺北市' aqi=46 status='良好' pm25=10.0 so2=0.0 co=0.2
# site_name='萬華' county='臺北市' aqi=50 status='良好' pm25=15.0 so2=1.7 co=0.22
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=13.0 so2=2.2 co=0.26
# site_name='士林' county='臺北市' aqi=58 status='普通' pm25=10.0 so2=0.6 co=0.18
# site_name='淡水' county='新北市' aqi=44 status='良好' pm25=10.0 so2=1.9 co=0.21
# site_name='林口' county='新北市' aqi=47 status='良好' pm25=10.0 so2=0.7 co=0.18
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=18.0 so2=1.6 co=0.22
# site_name='新莊' county='新北市' aqi=54 status='普通' pm25=17.0 so2=1.0 co=0.18
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=9.0 so2=1.0 co=0.27
# site_name='土城' county='新北市' aqi=53 status='普通' pm25=20.0 so2=1.1 co=0.23
# site_name='新店' county='新北市' aqi=50 status='良好' pm25=16.0 so2=1.7 co=0.2
# site_name='萬里' county='新北市' aqi=97 status='普通' pm25=8.0 so2=0.9 co=0.14
# site_name='汐止' county='新北市' aqi=48 status='良好' pm25=11.0 so2=0.7 co=0.16
# site_name='基隆' county='基隆市' aqi=71 status='普通' pm25=10.0 so2=1.2 co=0.18
# site_name='屏東(枋山)' county='屏東縣' aqi=45 status='良好' pm25=2.0 so2=0.4 co=0.14
# site_name='大甲（日南國小）' county='臺中市' aqi=37 status='良好' pm25=0.0 so2=0.9 co=0.12
# site_name='新北(樹林)' county='新北市' aqi=51 status='普通' pm25=15.0 so2=0.2 co=0.24
# site_name='屏東（琉球）' county='屏東縣' aqi=52 status='普通' pm25=31.0 so2=1.0 co=0.3
# site_name='臺南（麻豆）' county='臺南市' aqi=55 status='普通' pm25=16.0 so2=0.7 co=0.2
# site_name='高雄（湖內）' county='高雄市' aqi=76 status='普通' pm25=21.0 so2=0.4 co=0.27
# site_name='彰化（員林）' county='彰化縣' aqi=43 status='良好' pm25=22.0 so2=1.7 co=0.39
# site_name='大城' county='彰化縣' aqi=38 status='良好' pm25=18.0 so2=1.5 co=0.16
# site_name='富貴角' county='新北市' aqi=97 status='普通' pm25=14.0 so2=0.2 co=0.13
# site_name='麥寮' county='雲林縣' aqi=43 status='良好' pm25=14.0 so2=2.5 co=0.22
# site_name='關山' county='臺東縣' aqi=43 status='良好' pm25=2.0 so2=1.3 co=0.16
# site_name='馬公' county='澎湖縣' aqi=74 status='普通' pm25=11.0 so2=1.1 co=0.18
# site_name='金門' county='金門縣' aqi=87 status='普通' pm25=12.0 so2=2.0 co=0.22
# site_name='馬祖' county='連江縣' aqi=84 status='普通' pm25=15.0 so2=1.1 co=0.18
# site_name='埔里' county='南投縣' aqi=23 status='良好' pm25=4.0 so2=0.8 co=0.17
# site_name='復興' county='高雄市' aqi=36 status='良好' pm25=10.0 so2=1.5 co=0.36
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=15.0 so2=1.1 co=0.29
# site_name='竹山' county='南投縣' aqi=53 status='普通' pm25=10.0 so2=0.9 co=0.15
# site_name='中壢' county='桃園市' aqi=46 status='良好' pm25=14.0 so2=1.7 co=0.62
# site_name='三重' county='新北市' aqi=48 status='良好' pm25=15.0 so2=2.3 co=0.58
# site_name='冬山' county='宜蘭縣' aqi=39 status='良好' pm25=7.0 so2=0.0 co=0.17
# site_name='宜蘭' county='宜蘭縣' aqi=41 status='良好' pm25=10.0 so2=0.7 co=0.19
# site_name='陽明' county='臺北市' aqi=74 status='普通' pm25=6.0 so2=0.8 co=0.15
# site_name='花蓮' county='花蓮縣' aqi=44 status='良好' pm25=15.0 so2=1.1 co=0.24
# site_name='臺東' county='臺東縣' aqi=44 status='良好' pm25=13.0 so2=0.4 co=0.2
# site_name='恆春' county='屏東縣' aqi=50 status='良好' pm25=11.0 so2=0.6 co=0.16
# site_name='潮州' county='屏東縣' aqi=25 status='良好' pm25=19.0 so2=0.9 co=0.25
# site_name='屏東' county='屏東縣' aqi=26 status='良好' pm25=15.0 so2=1.1 co=0.28
# site_name='小港' county='高雄市' aqi=55 status='普通' pm25=14.0 so2=2.1 co=0.0
# site_name='前鎮' county='高雄市' aqi=42 status='良好' pm25=12.0 so2=2.8 co=0.28
# site_name='前金' county='高雄市' aqi=36 status='良好' pm25=12.0 so2=0.7 co=0.31
# site_name='左營' county='高雄市' aqi=67 status='普通' pm25=26.0 so2=1.1 co=0.31
# site_name='楠梓' county='高雄市' aqi=65 status='普通' pm25=28.0 so2=1.1 co=0.36
# site_name='林園' county='高雄市' aqi=40 status='良好' pm25=0.0 so2=2.3 co=0.25
# site_name='大寮' county='高雄市' aqi=49 status='良好' pm25=36.0 so2=4.9 co=0.65
# site_name='鳳山' county='高雄市' aqi=52 status='普通' pm25=20.0 so2=1.4 co=0.62
# site_name='仁武' county='高雄市' aqi=54 status='普通' pm25=22.0 so2=0.5 co=0.38
# site_name='橋頭' county='高雄市' aqi=78 status='普通' pm25=35.0 so2=1.3 co=0.39
# site_name='美濃' county='高雄市' aqi=19 status='良好' pm25=0.0 so2=0.6 co=0.18
# site_name='臺南' county='臺南市' aqi=70 status='普通' pm25=16.0 so2=0.5 co=0.27
# site_name='安南' county='臺南市' aqi=57 status='普通' pm25=12.0 so2=0.4 co=0.23
# site_name='善化' county='臺南市' aqi=66 status='普通' pm25=19.0 so2=1.1 co=0.2
# site_name='新營' county='臺南市' aqi=44 status='良好' pm25=10.0 so2=1.2 co=0.23
# site_name='嘉義' county='嘉義市' aqi=59 status='普通' pm25=16.0 so2=1.9 co=0.3
# site_name='臺西' county='雲林縣' aqi=39 status='良好' pm25=12.0 so2=1.8 co=0.19
# site_name='朴子' county='嘉義縣' aqi=27 status='良好' pm25=0.0 so2=1.2 co=0.32
# site_name='新港' county='嘉義縣' aqi=56 status='普通' pm25=21.0 so2=1.8 co=0.25
# site_name='崙背' county='雲林縣' aqi=46 status='良好' pm25=15.0 so2=1.8 co=0.51
# site_name='斗六' county='雲林縣' aqi=54 status='普通' pm25=18.0 so2=1.4 co=0.27
# site_name='南投' county='南投縣' aqi=34 status='良好' pm25=11.0 so2=0.6 co=0.35
# site_name='二林' county='彰化縣' aqi=44 status='良好' pm25=17.0 so2=2.1 co=0.51
# site_name='線西' county='彰化縣' aqi=32 status='良好' pm25=9.0 so2=4.7 co=0.62
# site_name='彰化' county='彰化縣' aqi=29 status='良好' pm25=13.0 so2=0.9 co=0.35
# site_name='西屯' county='臺中市' aqi=38 status='良好' pm25=12.0 so2=0.9 co=0.25
# site_name='忠明' county='臺中市' aqi=40 status='良好' pm25=7.0 so2=1.2 co=0.4
# site_name='大里' county='臺中市' aqi=42 status='良好' pm25=12.0 so2=1.7 co=0.46
# site_name='沙鹿' county='臺中市' aqi=35 status='良好' pm25=12.0 so2=1.2 co=0.25
# site_name='豐原' county='臺中市' aqi=26 status='良好' pm25=19.0 so2=1.4 co=0.36
# site_name='三義' county='苗栗縣' aqi=31 status='良好' pm25=11.0 so2=1.0 co=0.2
# site_name='苗栗' county='苗栗縣' aqi=44 status='良好' pm25=10.0 so2=1.2 co=0.21
# site_name='頭份' county='苗栗縣' aqi=44 status='良好' pm25=16.0 so2=2.0 co=0.24
# site_name='新竹' county='新竹市' aqi=49 status='良好' pm25=11.0 so2=1.1 co=0.28
# site_name='竹東' county='新竹縣' aqi=45 status='良好' pm25=13.0 so2=0.3 co=0.2
# site_name='湖口' county='新竹縣' aqi=51 status='普通' pm25=18.0 so2=1.7 co=0.23
# site_name='龍潭' county='桃園市' aqi=47 status='良好' pm25=14.0 so2=0.8 co=0.24
# site_name='平鎮' county='桃園市' aqi=48 status='良好' pm25=12.0 so2=1.3 co=0.31
# site_name='觀音' county='桃園市' aqi=54 status='普通' pm25=14.0 so2=1.0 co=0.14
# site_name='大園' county='桃園市' aqi=45 status='良好' pm25=13.0 so2=1.6 co=0.18
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=13.0 so2=0.5 co=0.28
# site_name='大同' county='臺北市' aqi=48 status='良好' pm25=20.0 so2=1.8 co=0.38
# site_name='松山' county='臺北市' aqi=48 status='良好' pm25=11.0 so2=1.1 co=0.2
# site_name='古亭' county='臺北市' aqi=47 status='良好' pm25=14.0 so2=0.0 co=0.23
# site_name='萬華' county='臺北市' aqi=50 status='良好' pm25=14.0 so2=0.8 co=0.25
# site_name='中山' county='臺北市' aqi=44 status='良好' pm25=10.0 so2=1.7 co=0.29
# site_name='士林' county='臺北市' aqi=61 status='普通' pm25=14.0 so2=0.6 co=0.18
# site_name='淡水' county='新北市' aqi=43 status='良好' pm25=9.0 so2=2.1 co=0.19
# site_name='林口' county='新北市' aqi=48 status='良好' pm25=11.0 so2=1.2 co=0.21
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=14.0 so2=2.4 co=0.24
# site_name='新莊' county='新北市' aqi=54 status='普通' pm25=14.0 so2=0.4 co=0.2
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=11.0 so2=0.9 co=0.27
# site_name='土城' county='新北市' aqi=52 status='普通' pm25=14.0 so2=1.1 co=0.24
# site_name='新店' county='新北市' aqi=51 status='普通' pm25=19.0 so2=1.7 co=0.21
# site_name='萬里' county='新北市' aqi=97 status='普通' pm25=10.0 so2=1.1 co=0.14
# site_name='汐止' county='新北市' aqi=46 status='良好' pm25=10.0 so2=0.5 co=0.16
# site_name='基隆' county='基隆市' aqi=74 status='普通' pm25=10.0 so2=1.1 co=0.18
# site_name='屏東(枋山)' county='屏東縣' aqi=45 status='良好' pm25=0.0 so2=0.3 co=0.14
# site_name='大甲（日南國小）' county='臺中市' aqi=37 status='良好' pm25=7.0 so2=0.0 co=0.14
# site_name='新北(樹林)' county='新北市' aqi=53 status='普通' pm25=14.0 so2=0.1 co=0.24
# site_name='屏東（琉球）' county='屏東縣' aqi=36 status='良好' pm25=0.0 so2=1.6 co=0.28
# site_name='臺南（麻豆）' county='臺南市' aqi=56 status='普通' pm25=17.0 so2=0.5 co=0.22
# site_name='高雄（湖內）' county='高雄市' aqi=78 status='普通' pm25=25.0 so2=0.4 co=0.32
# site_name='彰化（員林）' county='彰化縣' aqi=39 status='良好' pm25=13.0 so2=1.6 co=0.41
# site_name='大城' county='彰化縣' aqi=32 status='良好' pm25=0.0 so2=2.3 co=0.17
# site_name='富貴角' county='新北市' aqi=100 status='普通' pm25=12.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=43 status='良好' pm25=16.0 so2=2.6 co=0.26
# site_name='關山' county='臺東縣' aqi=43 status='良好' pm25=3.0 so2=1.2 co=0.17
# site_name='馬公' county='澎湖縣' aqi=74 status='普通' pm25=0.0 so2=1.1 co=0.18
# site_name='金門' county='金門縣' aqi=80 status='普通' pm25=13.0 so2=1.8 co=0.21
# site_name='馬祖' county='連江縣' aqi=80 status='普通' pm25=15.0 so2=1.1 co=0.19
# site_name='埔里' county='南投縣' aqi=26 status='良好' pm25=6.0 so2=0.8 co=0.21
# site_name='復興' county='高雄市' aqi=37 status='良好' pm25=17.0 so2=0.9 co=0.42
# site_name='永和' county='新北市' aqi=47 status='良好' pm25=15.0 so2=1.2 co=0.32
# site_name='竹山' county='南投縣' aqi=57 status='普通' pm25=18.0 so2=0.8 co=0.23
# site_name='中壢' county='桃園市' aqi=46 status='良好' pm25=14.0 so2=1.4 co=0.64
# site_name='三重' county='新北市' aqi=55 status='普通' pm25=13.0 so2=2.2 co=0.68
# site_name='冬山' county='宜蘭縣' aqi=38 status='良好' pm25=9.0 so2=0.0 co=0.16
# site_name='宜蘭' county='宜蘭縣' aqi=39 status='良好' pm25=9.0 so2=0.8 co=0.16
# site_name='陽明' county='臺北市' aqi=77 status='普通' pm25=7.0 so2=0.8 co=0.16
# site_name='花蓮' county='花蓮縣' aqi=44 status='良好' pm25=11.0 so2=1.4 co=0.28
# site_name='臺東' county='臺東縣' aqi=43 status='良好' pm25=7.0 so2=0.4 co=0.21
# site_name='恆春' county='屏東縣' aqi=50 status='良好' pm25=9.0 so2=0.6 co=0.16
# site_name='潮州' county='屏東縣' aqi=20 status='良好' pm25=0.0 so2=0.6 co=0.15
# site_name='屏東' county='屏東縣' aqi=19 status='良好' pm25=3.0 so2=0.8 co=0.21
# site_name='小港' county='高雄市' aqi=57 status='普通' pm25=21.0 so2=2.3 co=0.35
# site_name='前鎮' county='高雄市' aqi=44 status='良好' pm25=17.0 so2=2.5 co=0.34
# site_name='前金' county='高雄市' aqi=33 status='良好' pm25=15.0 so2=0.6 co=0.32
# site_name='左營' county='高雄市' aqi=65 status='普通' pm25=28.0 so2=0.9 co=0.36
# site_name='楠梓' county='高雄市' aqi=62 status='普通' pm25=24.0 so2=0.8 co=0.35
# site_name='林園' county='高雄市' aqi=26 status='良好' pm25=0.0 so2=3.0 co=0.31
# site_name='大寮' county='高雄市' aqi=34 status='良好' pm25=19.0 so2=2.0 co=0.39
# site_name='鳳山' county='高雄市' aqi=48 status='良好' pm25=19.0 so2=1.4 co=0.77
# site_name='仁武' county='高雄市' aqi=50 status='良好' pm25=23.0 so2=0.6 co=0.35
# site_name='橋頭' county='高雄市' aqi=71 status='普通' pm25=32.0 so2=1.0 co=0.34
# site_name='美濃' county='高雄市' aqi=14 status='良好' pm25=0.0 so2=0.6 co=0.2
# site_name='臺南' county='臺南市' aqi=75 status='普通' pm25=21.0 so2=0.6 co=0.29
# site_name='安南' county='臺南市' aqi=61 status='普通' pm25=16.0 so2=0.3 co=0.25
# site_name='善化' county='臺南市' aqi=68 status='普通' pm25=23.0 so2=0.6 co=0.24
# site_name='新營' county='臺南市' aqi=47 status='良好' pm25=14.0 so2=1.1 co=0.28
# site_name='嘉義' county='嘉義市' aqi=61 status='普通' pm25=12.0 so2=1.5 co=0.27
# site_name='臺西' county='雲林縣' aqi=38 status='良好' pm25=12.0 so2=2.0 co=0.19
# site_name='朴子' county='嘉義縣' aqi=24 status='良好' pm25=0.0 so2=1.0 co=0.3
# site_name='新港' county='嘉義縣' aqi=54 status='普通' pm25=18.0 so2=1.6 co=0.24
# site_name='崙背' county='雲林縣' aqi=44 status='良好' pm25=21.0 so2=1.5 co=0.43
# site_name='斗六' county='雲林縣' aqi=53 status='普通' pm25=19.0 so2=1.3 co=0.26
# site_name='南投' county='南投縣' aqi=33 status='良好' pm25=13.0 so2=0.5 co=0.4
# site_name='二林' county='彰化縣' aqi=40 status='良好' pm25=17.0 so2=1.5 co=0.51
# site_name='線西' county='彰化縣' aqi=34 status='良好' pm25=7.0 so2=1.8 co=0.27
# site_name='彰化' county='彰化縣' aqi=27 status='良好' pm25=11.0 so2=0.8 co=0.28
# site_name='西屯' county='臺中市' aqi=38 status='良好' pm25=16.0 so2=1.5 co=0.3
# site_name='忠明' county='臺中市' aqi=35 status='良好' pm25=9.0 so2=1.2 co=0.49
# site_name='大里' county='臺中市' aqi=41 status='良好' pm25=16.0 so2=2.3 co=0.41
# site_name='沙鹿' county='臺中市' aqi=34 status='良好' pm25=8.0 so2=1.2 co=0.24
# site_name='豐原' county='臺中市' aqi=23 status='良好' pm25=0.0 so2=2.8 co=0.3
# site_name='三義' county='苗栗縣' aqi=31 status='良好' pm25=8.0 so2=0.9 co=0.21
# site_name='苗栗' county='苗栗縣' aqi=43 status='良好' pm25=11.0 so2=1.1 co=0.16
# site_name='頭份' county='苗栗縣' aqi=44 status='良好' pm25=10.0 so2=1.7 co=0.24
# ...
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=16.0 so2=1.1 co=0.54
# site_name='竹山' county='南投縣' aqi=52 status='普通' pm25=21.0 so2=0.9 co=0.46
# site_name='中壢' county='桃園市' aqi=44 status='良好' pm25=17.0 so2=1.6 co=0.66
# site_name='三重' county='新北市' aqi=55 status='普通' pm25=13.0 so2=1.2 co=0.87
# site_name='冬山' county='宜蘭縣' aqi=39 status='良好' pm25=9.0 so2=0.3 co=0.17
# site_name='宜蘭' county='宜蘭縣' aqi=35 status='良好' pm25=6.0 so2=0.9 co=0.18
# site_name='陽明' county='臺北市' aqi=77 status='普通' pm25=6.0 so2=0.8 co=0.16
# site_name='花蓮' county='花蓮縣' aqi=44 status='良好' pm25=10.0 so2=1.2 co=0.27
# site_name='臺東' county='臺東縣' aqi=43 status='良好' pm25=9.0 so2=0.3 co=0.25
# site_name='恆春' county='屏東縣' aqi=49 status='良好' pm25=7.0 so2=0.6 co=0.17
# site_name='潮州' county='屏東縣' aqi=20 status='良好' pm25=5.0 so2=0.3 co=0.2
# site_name='屏東' county='屏東縣' aqi=19 status='良好' pm25=5.0 so2=0.7 co=0.25
# site_name='小港' county='高雄市' aqi=45 status='良好' pm25=20.0 so2=1.4 co=0.57
# site_name='前鎮' county='高雄市' aqi=36 status='良好' pm25=18.0 so2=1.2 co=0.6
# site_name='前金' county='高雄市' aqi=25 status='良好' pm25=9.0 so2=0.3 co=0.39
# site_name='左營' county='高雄市' aqi=46 status='良好' pm25=21.0 so2=0.7 co=0.46
# site_name='楠梓' county='高雄市' aqi=57 status='普通' pm25=27.0 so2=1.1 co=0.42
# site_name='林園' county='高雄市' aqi=28 status='良好' pm25=7.0 so2=3.3 co=0.29
# site_name='大寮' county='高雄市' aqi=29 status='良好' pm25=9.0 so2=1.4 co=0.27
# site_name='鳳山' county='高雄市' aqi=33 status='良好' pm25=20.0 so2=1.4 co=0.77
# site_name='仁武' county='高雄市' aqi=40 status='良好' pm25=14.0 so2=0.0 co=0.52
# site_name='橋頭' county='高雄市' aqi=59 status='普通' pm25=27.0 so2=1.0 co=0.43
# site_name='美濃' county='高雄市' aqi=12 status='良好' pm25=3.0 so2=0.5 co=0.21
# site_name='臺南' county='臺南市' aqi=74 status='普通' pm25=22.0 so2=0.5 co=0.43
# site_name='安南' county='臺南市' aqi=59 status='普通' pm25=24.0 so2=0.6 co=0.37
# site_name='善化' county='臺南市' aqi=65 status='普通' pm25=27.0 so2=0.9 co=0.3
# site_name='新營' county='臺南市' aqi=45 status='良好' pm25=18.0 so2=1.5 co=0.35
# site_name='嘉義' county='嘉義市' aqi=68 status='普通' pm25=25.0 so2=2.1 co=0.48
# site_name='臺西' county='雲林縣' aqi=35 status='良好' pm25=13.0 so2=2.0 co=0.24
# site_name='朴子' county='嘉義縣' aqi=23 status='良好' pm25=0.0 so2=0.9 co=0.23
# site_name='新港' county='嘉義縣' aqi=51 status='普通' pm25=15.0 so2=1.3 co=0.25
# site_name='崙背' county='雲林縣' aqi=36 status='良好' pm25=12.0 so2=1.3 co=0.22
# site_name='斗六' county='雲林縣' aqi=50 status='良好' pm25=14.0 so2=1.2 co=0.36
# site_name='南投' county='南投縣' aqi=32 status='良好' pm25=14.0 so2=0.8 co=0.49
# site_name='二林' county='彰化縣' aqi=36 status='良好' pm25=14.0 so2=0.7 co=0.21
# site_name='線西' county='彰化縣' aqi=37 status='良好' pm25=4.0 so2=1.3 co=0.19
# site_name='彰化' county='彰化縣' aqi=30 status='良好' pm25=8.0 so2=0.9 co=0.38
# site_name='西屯' county='臺中市' aqi=34 status='良好' pm25=11.0 so2=1.6 co=0.39
# site_name='忠明' county='臺中市' aqi=37 status='良好' pm25=8.0 so2=1.6 co=0.61
# site_name='大里' county='臺中市' aqi=35 status='良好' pm25=14.0 so2=2.5 co=0.52
# site_name='沙鹿' county='臺中市' aqi=35 status='良好' pm25=7.0 so2=1.1 co=0.24
# site_name='豐原' county='臺中市' aqi=19 status='良好' pm25=2.0 so2=0.8 co=0.34
# site_name='三義' county='苗栗縣' aqi=36 status='良好' pm25=4.0 so2=0.8 co=0.21
# site_name='苗栗' county='苗栗縣' aqi=44 status='良好' pm25=14.0 so2=1.2 co=0.22
# site_name='頭份' county='苗栗縣' aqi=44 status='良好' pm25=13.0 so2=1.6 co=0.29
# site_name='新竹' county='新竹市' aqi=49 status='良好' pm25=7.0 so2=1.0 co=0.3
# site_name='竹東' county='新竹縣' aqi=45 status='良好' pm25=10.0 so2=0.7 co=0.19
# site_name='湖口' county='新竹縣' aqi=51 status='普通' pm25=11.0 so2=2.1 co=0.25
# site_name='龍潭' county='桃園市' aqi=49 status='良好' pm25=10.0 so2=1.0 co=0.23
# site_name='平鎮' county='桃園市' aqi=49 status='良好' pm25=11.0 so2=1.4 co=0.38
# site_name='觀音' county='桃園市' aqi=50 status='良好' pm25=14.0 so2=1.1 co=0.14
# site_name='大園' county='桃園市' aqi=46 status='良好' pm25=11.0 so2=1.9 co=0.2
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=14.0 so2=1.4 co=0.39
# site_name='大同' county='臺北市' aqi=53 status='普通' pm25=15.0 so2=1.3 co=0.91
# site_name='松山' county='臺北市' aqi=49 status='良好' pm25=16.0 so2=1.4 co=0.31
# site_name='古亭' county='臺北市' aqi=51 status='普通' pm25=10.0 so2=0.0 co=0.25
# site_name='萬華' county='臺北市' aqi=50 status='良好' pm25=16.0 so2=1.7 co=0.31
# site_name='中山' county='臺北市' aqi=45 status='良好' pm25=13.0 so2=1.8 co=0.4
# site_name='士林' county='臺北市' aqi=67 status='普通' pm25=10.0 so2=0.5 co=0.2
# site_name='淡水' county='新北市' aqi=37 status='良好' pm25=11.0 so2=1.6 co=0.21
# site_name='林口' county='新北市' aqi=50 status='良好' pm25=14.0 so2=0.4 co=0.24
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=12.0 so2=1.0 co=0.34
# site_name='新莊' county='新北市' aqi=51 status='普通' pm25=12.0 so2=1.5 co=0.26
# site_name='板橋' county='新北市' aqi=47 status='良好' pm25=9.0 so2=0.9 co=0.38
# site_name='土城' county='新北市' aqi=50 status='良好' pm25=17.0 so2=1.2 co=0.32
# site_name='新店' county='新北市' aqi=54 status='普通' pm25=13.0 so2=1.6 co=0.25
# site_name='萬里' county='新北市' aqi=100 status='普通' pm25=11.0 so2=1.0 co=0.15
# site_name='汐止' county='新北市' aqi=43 status='良好' pm25=10.0 so2=0.9 co=0.2
# site_name='基隆' county='基隆市' aqi=74 status='普通' pm25=10.0 so2=1.2 co=0.2
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=3.0 so2=0.3 co=0.15
# site_name='大甲（日南國小）' county='臺中市' aqi=41 status='良好' pm25=7.0 so2=0.0 co=0.24
# site_name='新北(樹林)' county='新北市' aqi=53 status='普通' pm25=22.0 so2=0.0 co=0.46
# site_name='屏東（琉球）' county='屏東縣' aqi=23 status='良好' pm25=10.0 so2=0.8 co=0.22
# site_name='臺南（麻豆）' county='臺南市' aqi=47 status='良好' pm25=18.0 so2=0.2 co=0.32
# site_name='高雄（湖內）' county='高雄市' aqi=66 status='普通' pm25=26.0 so2=0.0 co=0.4
# site_name='彰化（員林）' county='彰化縣' aqi=41 status='良好' pm25=16.0 so2=1.6 co=0.5
# site_name='大城' county='彰化縣' aqi=31 status='良好' pm25=7.0 so2=4.1 co=0.17
# site_name='富貴角' county='新北市' aqi=100 status='普通' pm25=17.0 so2=0.2 co=0.13
# site_name='麥寮' county='雲林縣' aqi=35 status='良好' pm25=15.0 so2=3.1 co=0.47
# site_name='關山' county='臺東縣' aqi=43 status='良好' pm25=10.0 so2=0.8 co=0.2
# site_name='馬公' county='澎湖縣' aqi=74 status='普通' pm25=5.0 so2=0.9 co=0.18
# site_name='金門' county='金門縣' aqi=71 status='普通' pm25=9.0 so2=1.7 co=0.19
# site_name='馬祖' county='連江縣' aqi=80 status='普通' pm25=16.0 so2=1.3 co=0.26
# site_name='埔里' county='南投縣' aqi=28 status='良好' pm25=8.0 so2=0.8 co=0.28
# site_name='復興' county='高雄市' aqi=28 status='良好' pm25=13.0 so2=0.8 co=0.87
# site_name='永和' county='新北市' aqi=48 status='良好' pm25=13.0 so2=0.9 co=0.61
# site_name='竹山' county='南投縣' aqi=49 status='良好' pm25=17.0 so2=1.0 co=0.33
# site_name='中壢' county='桃園市' aqi=45 status='良好' pm25=16.0 so2=2.3 co=0.94
# site_name='三重' county='新北市' aqi=57 status='普通' pm25=15.0 so2=1.2 co=1.19
# site_name='冬山' county='宜蘭縣' aqi=39 status='良好' pm25=10.0 so2=0.3 co=0.19
# site_name='宜蘭' county='宜蘭縣' aqi=37 status='良好' pm25=8.0 so2=1.6 co=0.21
# site_name='陽明' county='臺北市' aqi=77 status='普通' pm25=10.0 so2=0.7 co=0.16
# site_name='花蓮' county='花蓮縣' aqi=44 status='良好' pm25=10.0 so2=0.6 co=0.24
# site_name='臺東' county='臺東縣' aqi=43 status='良好' pm25=9.0 so2=0.3 co=0.21
# site_name='恆春' county='屏東縣' aqi=48 status='良好' pm25=9.0 so2=0.6 co=0.17
# site_name='潮州' county='屏東縣' aqi=19 status='良好' pm25=3.0 so2=0.2 co=0.17
# site_name='屏東' county='屏東縣' aqi=20 status='良好' pm25=6.0 so2=0.5 co=0.28
# site_name='小港' county='高雄市' aqi=43 status='良好' pm25=24.0 so2=0.9 co=0.55
# site_name='前鎮' county='高雄市' aqi=30 status='良好' pm25=19.0 so2=0.0 co=0.6
# site_name='前金' county='高雄市' aqi=26 status='良好' pm25=7.0 so2=0.3 co=0.4
# site_name='左營' county='高雄市' aqi=42 status='良好' pm25=0.0 so2=0.5 co=0.45
# site_name='楠梓' county='高雄市' aqi=51 status='普通' pm25=22.0 so2=1.1 co=0.44
# site_name='林園' county='高雄市' aqi=29 status='良好' pm25=0.0 so2=1.6 co=0.24
# site_name='大寮' county='高雄市' aqi=28 status='良好' pm25=10.0 so2=5.2 co=0.27
# site_name='鳳山' county='高雄市' aqi=27 status='良好' pm25=15.0 so2=0.9 co=0.68
# site_name='仁武' county='高雄市' aqi=39 status='良好' pm25=18.0 so2=0.0 co=0.48
# site_name='橋頭' county='高雄市' aqi=55 status='普通' pm25=18.0 so2=0.9 co=0.46
# site_name='美濃' county='高雄市' aqi=14 status='良好' pm25=3.0 so2=0.5 co=0.24
# site_name='臺南' county='臺南市' aqi=75 status='普通' pm25=28.0 so2=0.3 co=0.48
# site_name='安南' county='臺南市' aqi=56 status='普通' pm25=22.0 so2=0.3 co=0.37
# site_name='善化' county='臺南市' aqi=61 status='普通' pm25=25.0 so2=0.8 co=0.31
# site_name='新營' county='臺南市' aqi=41 status='良好' pm25=18.0 so2=1.3 co=0.34
# site_name='嘉義' county='嘉義市' aqi=67 status='普通' pm25=26.0 so2=1.7 co=0.44
# site_name='臺西' county='雲林縣' aqi=36 status='良好' pm25=8.0 so2=3.2 co=0.29
# site_name='朴子' county='嘉義縣' aqi=24 status='良好' pm25=0.0 so2=0.9 co=0.25
# site_name='新港' county='嘉義縣' aqi=53 status='普通' pm25=17.0 so2=1.4 co=0.24
# site_name='崙背' county='雲林縣' aqi=37 status='良好' pm25=11.0 so2=1.2 co=0.21
# site_name='斗六' county='雲林縣' aqi=49 status='良好' pm25=14.0 so2=1.1 co=0.3
# site_name='南投' county='南投縣' aqi=27 status='良好' pm25=9.0 so2=0.8 co=0.32
# site_name='二林' county='彰化縣' aqi=36 status='良好' pm25=9.0 so2=0.7 co=0.2
# site_name='線西' county='彰化縣' aqi=39 status='良好' pm25=5.0 so2=1.5 co=0.19
# site_name='彰化' county='彰化縣' aqi=28 status='良好' pm25=10.0 so2=0.9 co=0.39
# site_name='西屯' county='臺中市' aqi=33 status='良好' pm25=12.0 so2=1.3 co=0.26
# site_name='忠明' county='臺中市' aqi=24 status='良好' pm25=7.0 so2=1.6 co=0.34
# site_name='大里' county='臺中市' aqi=34 status='良好' pm25=11.0 so2=1.8 co=0.4
# site_name='沙鹿' county='臺中市' aqi=36 status='良好' pm25=6.0 so2=0.9 co=0.28
# site_name='豐原' county='臺中市' aqi=21 status='良好' pm25=3.0 so2=0.7 co=0.35
# site_name='三義' county='苗栗縣' aqi=38 status='良好' pm25=3.0 so2=0.9 co=0.19
# site_name='苗栗' county='苗栗縣' aqi=44 status='良好' pm25=8.0 so2=0.9 co=0.19
# site_name='頭份' county='苗栗縣' aqi=45 status='良好' pm25=10.0 so2=1.6 co=0.23
# site_name='新竹' county='新竹市' aqi=49 status='良好' pm25=8.0 so2=1.2 co=0.28
# site_name='竹東' county='新竹縣' aqi=47 status='良好' pm25=12.0 so2=0.4 co=0.21
# site_name='湖口' county='新竹縣' aqi=51 status='普通' pm25=13.0 so2=1.8 co=0.23
# site_name='龍潭' county='桃園市' aqi=50 status='良好' pm25=10.0 so2=1.1 co=0.23
# site_name='平鎮' county='桃園市' aqi=49 status='良好' pm25=9.0 so2=1.7 co=0.41
# site_name='觀音' county='桃園市' aqi=50 status='良好' pm25=13.0 so2=1.5 co=0.18
# site_name='大園' county='桃園市' aqi=45 status='良好' pm25=12.0 so2=1.5 co=0.21
# site_name='桃園' county='桃園市' aqi=48 status='良好' pm25=11.0 so2=1.9 co=0.41
# site_name='大同' county='臺北市' aqi=52 status='普通' pm25=15.0 so2=1.1 co=0.69
# site_name='松山' county='臺北市' aqi=49 status='良好' pm25=13.0 so2=1.0 co=0.3
# site_name='古亭' county='臺北市' aqi=54 status='普通' pm25=11.0 so2=1.0 co=0.24
# site_name='萬華' county='臺北市' aqi=50 status='良好' pm25=18.0 so2=1.9 co=0.29
# site_name='中山' county='臺北市' aqi=46 status='良好' pm25=10.0 so2=1.6 co=0.43
# site_name='士林' county='臺北市' aqi=71 status='普通' pm25=10.0 so2=0.5 co=0.21
# site_name='淡水' county='新北市' aqi=37 status='良好' pm25=13.0 so2=1.6 co=0.24
# site_name='林口' county='新北市' aqi=51 status='普通' pm25=12.0 so2=0.3 co=0.25
# site_name='菜寮' county='新北市' aqi=51 status='普通' pm25=12.0 so2=1.0 co=0.34
# site_name='新莊' county='新北市' aqi=51 status='普通' pm25=11.0 so2=1.2 co=0.26
# site_name='板橋' county='新北市' aqi=48 status='良好' pm25=7.0 so2=0.9 co=0.39
# site_name='土城' county='新北市' aqi=50 status='良好' pm25=16.0 so2=1.1 co=0.36
# site_name='新店' county='新北市' aqi=54 status='普通' pm25=13.0 so2=1.6 co=0.27
# site_name='萬里' county='新北市' aqi=97 status='普通' pm25=11.0 so2=0.9 co=0.16
# site_name='汐止' county='新北市' aqi=42 status='良好' pm25=11.0 so2=0.6 co=0.28
# site_name='基隆' county='基隆市' aqi=74 status='普通' pm25=11.0 so2=1.3 co=0.23
# site_name='屏東(枋山)' county='屏東縣' aqi=44 status='良好' pm25=2.0 so2=0.4 co=0.15
# site_name='大甲（日南國小）' county='臺中市' aqi=43 status='良好' pm25=11.0 so2=0.0 co=0.18
# site_name='新北(樹林)' county='新北市' aqi=49 status='良好' pm25=14.0 so2=0.1 co=0.27
# site_name='屏東（琉球）' county='屏東縣' aqi=21 status='良好' pm25=10.0 so2=0.6 co=0.19
# site_name='臺南（麻豆）' county='臺南市' aqi=45 status='良好' pm25=12.0 so2=0.2 co=0.29
# site_name='高雄（湖內）' county='高雄市' aqi=64 status='普通' pm25=23.0 so2=0.0 co=0.34
# site_name='彰化（員林）' county='彰化縣' aqi=38 status='良好' pm25=9.0 so2=1.8 co=0.31
# site_name='大城' county='彰化縣' aqi=35 status='良好' pm25=10.0 so2=4.1 co=0.31
# site_name='富貴角' county='新北市' aqi=100 status='普通' pm25=16.0 so2=0.1 co=0.13
# site_name='麥寮' county='雲林縣' aqi=35 status='良好' pm25=4.0 so2=2.5 co=0.32
# site_name='關山' county='臺東縣' aqi=43 status='良好' pm25=10.0 so2=0.8 co=0.16
# site_name='馬公' county='澎湖縣' aqi=74 status='普通' pm25=9.0 so2=0.7 co=0.15
# site_name='金門' county='金門縣' aqi=71 status='普通' pm25=10.0 so2=1.6 co=0.17
# site_name='馬祖' county='連江縣' aqi=80 status='普通' pm25=11.0 so2=1.1 co=0.16
# site_name='埔里' county='南投縣' aqi=30 status='良好' pm25=6.0 so2=0.7 co=0.23
# site_name='復興' county='高雄市' aqi=30 status='良好' pm25=12.0 so2=0.4 co=0.65
# site_name='永和' county='新北市' aqi=49 status='良好' pm25=12.0 so2=1.0 co=0.26
# site_name='竹山' county='南投縣' aqi=47 status='良好' pm25=11.0 so2=1.0 co=0.28
# site_name='中壢' county='桃園市' aqi=44 status='良好' pm25=11.0 so2=2.3 co=0.54
# site_name='三重' county='新北市' aqi=54 status='普通' pm25=11.0 so2=1.1 co=0.68
# site_name='冬山' county='宜蘭縣' aqi=41 status='良好' pm25=8.0 so2=0.3 co=0.15
# site_name='宜蘭' county='宜蘭縣' aqi=37 status='良好' pm25=11.0 so2=1.0 co=0.16
# site_name='陽明' county='臺北市' aqi=74 status='普通' pm25=11.0 so2=0.8 co=0.16
# site_name='花蓮' county='花蓮縣' aqi=46 status='良好' pm25=14.0 so2=0.4 co=0.21
# site_name='臺東' county='臺東縣' aqi=42 status='良好' pm25=5.0 so2=0.3 co=0.17
# site_name='恆春' county='屏東縣' aqi=47 status='良好' pm25=9.0 so2=0.5 co=0.17
# site_name='潮州' county='屏東縣' aqi=18 status='良好' pm25=4.0 so2=0.3 co=0.18
# site_name='屏東' county='屏東縣' aqi=21 status='良好' pm25=3.0 so2=0.4 co=0.21
# site_name='小港' county='高雄市' aqi=33 status='良好' pm25=11.0 so2=0.6 co=0.35
# site_name='前鎮' county='高雄市' aqi=30 status='良好' pm25=10.0 so2=0.8 co=0.43
# site_name='前金' county='高雄市' aqi=29 status='良好' pm25=11.0 so2=0.2 co=0.33
# site_name='左營' county='高雄市' aqi=41 status='良好' pm25=13.0 so2=0.4 co=0.41
# site_name='楠梓' county='高雄市' aqi=45 status='良好' pm25=17.0 so2=0.5 co=0.38
# site_name='林園' county='高雄市' aqi=26 status='良好' pm25=14.0 so2=0.9 co=0.23
# site_name='大寮' county='高雄市' aqi=28 status='良好' pm25=10.0 so2=2.6 co=0.27
# site_name='鳳山' county='高雄市' aqi=25 status='良好' pm25=11.0 so2=0.7 co=0.5
# site_name='仁武' county='高雄市' aqi=35 status='良好' pm25=15.0 so2=0.0 co=0.36
# site_name='橋頭' county='高雄市' aqi=53 status='普通' pm25=20.0 so2=0.8 co=0.38
# site_name='美濃' county='高雄市' aqi=15 status='良好' pm25=2.0 so2=0.4 co=0.23
# site_name='臺南' county='臺南市' aqi=72 status='普通' pm25=28.0 so2=0.0 co=0.44
# site_name='安南' county='臺南市' aqi=52 status='普通' pm25=18.0 so2=0.1 co=0.34
# site_name='善化' county='臺南市' aqi=58 status='普通' pm25=20.0 so2=1.0 co=0.25
# site_name='新營' county='臺南市' aqi=36 status='良好' pm25=14.0 so2=1.2 co=0.29
# site_name='嘉義' county='嘉義市' aqi=64 status='普通' pm25=22.0 so2=1.3 co=0.34
# site_name='臺西' county='雲林縣' aqi=39 status='良好' pm25=10.0 so2=3.4 co=0.38
# site_name='朴子' county='嘉義縣' aqi=26 status='良好' pm25=0.0 so2=0.9 co=0.26
# site_name='新港' county='嘉義縣' aqi=53 status='普通' pm25=22.0 so2=1.3 co=0.23
# site_name='崙背' county='雲林縣' aqi=37 status='良好' pm25=11.0 so2=1.2 co=0.2
# site_name='斗六' county='雲林縣' aqi=50 status='良好' pm25=15.0 so2=1.1 co=0.27
# site_name='南投' county='南投縣' aqi=25 status='良好' pm25=7.0 so2=0.8 co=0.23
# site_name='二林' county='彰化縣' aqi=38 status='良好' pm25=10.0 so2=0.6 co=0.18
# site_name='線西' county='彰化縣' aqi=42 status='良好' pm25=8.0 so2=1.0 co=0.15
# site_name='彰化' county='彰化縣' aqi=27 status='良好' pm25=9.0 so2=0.8 co=0.22
# site_name='西屯' county='臺中市' aqi=31 status='良好' pm25=13.0 so2=1.3 co=0.2
# site_name='忠明' county='臺中市' aqi=25 status='良好' pm25=7.0 so2=1.8 co=0.23
# site_name='大里' county='臺中市' aqi=32 status='良好' pm25=13.0 so2=1.7 co=0.29
# site_name='沙鹿' county='臺中市' aqi=38 status='良好' pm25=7.0 so2=0.8 co=0.2
# site_name='豐原' county='臺中市' aqi=23 status='良好' pm25=6.0 so2=0.7 co=0.24
# site_name='三義' county='苗栗縣' aqi=40 status='良好' pm25=3.0 so2=0.8 co=0.17
# site_name='苗栗' county='苗栗縣' aqi=45 status='良好' pm25=10.0 so2=1.0 co=0.12
# site_name='頭份' county='苗栗縣' aqi=46 status='良好' pm25=9.0 so2=1.6 co=0.17
# site_name='新竹' county='新竹市' aqi=50 status='良好' pm25=7.0 so2=0.8 co=0.2
# site_name='竹東' county='新竹縣' aqi=48 status='良好' pm25=10.0 so2=0.3 co=0.17
# site_name='湖口' county='新竹縣' aqi=51 status='普通' pm25=17.0 so2=1.6 co=0.19
# site_name='龍潭' county='桃園市' aqi=51 status='普通' pm25=11.0 so2=1.0 co=0.18
