# %%
import numpy as np
import pandas as pd
array_2d = np.random.randint(50,100,size=(50,5))
df1 = pd.DataFrame(array_2d,
             columns=['國文','英文','數學','地理','社會'],
             index = [f'{num}號' for num in range(1,51)]
             )
df1

# %%
total_se = df1['國文'] + df1['英文'] + df1['數學'] + df1['地理'] + df1['社會']

# %%
average_se = total_se / 5
average_se

# %%
df1['總分'] = total_se
df1['平均'] = average_se
df1

# %%
#Series使用比較運算子
df1['總分'] >= 400

# %%
#dataFrame使用subscript,搜尋資料
#dataFrame[bool Series]

df1[df1['總分'] >= 400]
# Out:
#      國文  英文  數學  地理  社會   總分    平均
# 3號   82  82  79  99  77  419  83.8
# 7號   97  78  92  70  70  407  81.4
# 17號  91  74  67  92  88  412  82.4
# 19號  59  98  60  99  85  401  80.2
# 20號  81  78  55  98  91  403  80.6
# 21號  78  50  95  90  95  408  81.6
# 25號  54  75  96  93  90  408  81.6
# 27號  64  92  92  95  82  425  85.0
# 31號  86  79  72  83  95  415  83.0
# 35號  64  68  86  90  99  407  81.4
# 40號  99  91  95  53  71  409  81.8
# 47號  71  92  77  95  85  420  84.0
# 49號  95  90  83  71  82  421  84.2

# %%
#查詢國文95分以上的學生
df1[df1['國文']>=95]
# Out:
#      國文  英文  數學  地理  社會   總分    平均
# 7號   97  78  92  70  70  407  81.4
# 33號  96  75  79  61  66  377  75.4
# 38號  98  55  68  67  87  375  75.0
# 40號  99  91  95  53  71  409  81.8
# 49號  95  90  83  71  82  421  84.2

# %%
#查詢國文95分以上的學生同時總分400分以上
#and = &
#or = |
df1[(df1['國文']>=95) & (df1['總分']>=400)]
# Out:
#      國文  英文  數學  地理  社會   總分    平均
# 7號   97  78  92  70  70  407  81.4
# 40號  99  91  95  53  71  409  81.8
# 49號  95  90  83  71  82  421  84.2
