# %%
import json
import pandas as pd
with open('每日各站進出站人數/車站基本資料集.json',encoding='utf-8') as file:
    content:list[dict] = json.load(file)
info_df = pd.DataFrame(content)
info_df1 = info_df.reindex(columns=['stationCode','stationName','stationAddrTw'])
info_df1.columns = ['code','站名','地址']
info_df1['code'] = info_df1['code'].astype(int)
info_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   code    243 non-null    int64
#  1   站名      243 non-null    object
#  2   地址      243 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 5.8+ KB

# %%
site_2023_df = pd.read_csv('每日各站進出站人數/每日各站進出站人數2023.csv')
site_2023_df.columns = ['日期','code','進站','出站']
site_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86609 entries, 0 to 86608
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      86609 non-null  int64
#  1   code    86609 non-null  int64
#  2   進站      86609 non-null  int64
#  3   出站      86609 non-null  int64
# dtypes: int64(4)
# memory usage: 2.6 MB

# %%
merge2023 = pd.merge(site_2023_df,info_df1)
merge2023
# Out:
#              日期  code    進站    出站   站名  \
# 0      20230101   900  8030  8241   基隆
# 1      20230101   910  1017  1326   三坑
# 2      20230101   920  1400  1705   八堵
# 3      20230101   930  3558  4398   七堵
# 4      20230101   940  1509  1815   百福
# ...         ...   ...   ...   ...  ...
# 86604  20231231  7360  7916  8252   瑞芳
# 86605  20231231  7361   164   195  海科館
# 86606  20231231  7362   652   720  八斗子
# 86607  20231231  7380  1526   656  四腳亭
# 86608  20231231  7390   576   447   暖暖
#
#                                                   地址
# 0                                        基隆市仁愛區港西街5號
# 1                                 基隆市仁愛區德厚里龍安街 206 號
# 2                                 基隆市暖暖區八南里八堵路 142 號
# 3                                   基隆市七堵區長興里東新街 2 號
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號
# ...                                              ...
# 86604                            新北市瑞芳區龍潭里明燈路三段 82 號
# 86605                                      基隆市中正區長潭里
# 86606  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 86607                              新北市瑞芳區吉慶里中央路 65 號
# 86608                              基隆市暖暖區暖暖里暖暖街 51 號
#
# [86609 rows x 6 columns]

# %%
merge2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86609 entries, 0 to 86608
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      86609 non-null  int64
#  1   code    86609 non-null  int64
#  2   進站      86609 non-null  int64
#  3   出站      86609 non-null  int64
#  4   站名      86609 non-null  object
#  5   地址      86609 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 4.0+ MB

# %%
merge2023['日期'] = pd.to_datetime(merge2023['日期'].astype(str))

# %%
merge2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86609 entries, 0 to 86608
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      86609 non-null  datetime64[ns]
#  1   code    86609 non-null  int64
#  2   進站      86609 non-null  int64
#  3   出站      86609 non-null  int64
#  4   站名      86609 non-null  object
#  5   地址      86609 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 4.0+ MB

# %%
merge2023_1 = merge2023.set_index('日期')
merge2023_2 = merge2023_1.reindex(columns=['站名','地址','進站','出站'])
merge2023_2
# Out:
#              站名                                             地址    進站    出站
# 日期
# 2023-01-01   基隆                                    基隆市仁愛區港西街5號  8030  8241
# 2023-01-01   三坑                             基隆市仁愛區德厚里龍安街 206 號  1017  1326
# 2023-01-01   八堵                             基隆市暖暖區八南里八堵路 142 號  1400  1705
# 2023-01-01   七堵                               基隆市七堵區長興里東新街 2 號  3558  4398
# 2023-01-01   百福                          基隆市七堵區堵南里明德三路 1 之 1 號  1509  1815
# ...         ...                                            ...   ...   ...
# 2023-12-31   瑞芳                            新北市瑞芳區龍潭里明燈路三段 82 號  7916  8252
# 2023-12-31  海科館                                      基隆市中正區長潭里   164   195
# 2023-12-31  八斗子  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)   652   720
# 2023-12-31  四腳亭                              新北市瑞芳區吉慶里中央路 65 號  1526   656
# 2023-12-31   暖暖                              基隆市暖暖區暖暖里暖暖街 51 號   576   447
#
# [86609 rows x 4 columns]

# %%
merge2023_2.loc['2023-01-01']
# Out:
#              站名                                             地址    進站    出站
# 日期
# 2023-01-01   基隆                                    基隆市仁愛區港西街5號  8030  8241
# 2023-01-01   三坑                             基隆市仁愛區德厚里龍安街 206 號  1017  1326
# 2023-01-01   八堵                             基隆市暖暖區八南里八堵路 142 號  1400  1705
# 2023-01-01   七堵                               基隆市七堵區長興里東新街 2 號  3558  4398
# 2023-01-01   百福                          基隆市七堵區堵南里明德三路 1 之 1 號  1509  1815
# ...         ...                                            ...   ...   ...
# 2023-01-01   瑞芳                            新北市瑞芳區龍潭里明燈路三段 82 號  4543  5222
# 2023-01-01  海科館                                      基隆市中正區長潭里    93   123
# 2023-01-01  八斗子  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)   415   429
# 2023-01-01  四腳亭                              新北市瑞芳區吉慶里中央路 65 號   485   495
# 2023-01-01   暖暖                              基隆市暖暖區暖暖里暖暖街 51 號   258   370
#
# [238 rows x 4 columns]
