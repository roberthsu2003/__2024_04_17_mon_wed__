# %%
import json
import pandas as pd
with open('每日各站進出站人數/車站基本資料集.json',encoding='utf-8') as file:
    content:list[dict] = json.load(file)
info_df = pd.DataFrame(content)
info_df1 = info_df.reindex(columns=['stationCode','stationName','name','stationAddrTw'])
info_df1.columns = ['code','站名','地名','地址']
info_df1
# Out:
#      code   站名   地名                                             地址
# 0    0900   基隆   基隆                                    基隆市仁愛區港西街5號
# 1    0910   三坑   三坑                             基隆市仁愛區德厚里龍安街 206 號
# 2    0920   八堵   八堵                             基隆市暖暖區八南里八堵路 142 號
# 3    0930   七堵   七堵                               基隆市七堵區長興里東新街 2 號
# 4    0940   百福   百福                          基隆市七堵區堵南里明德三路 1 之 1 號
# ..    ...  ...  ...                                            ...
# 238  7360   瑞芳   瑞芳                            新北市瑞芳區龍潭里明燈路三段 82 號
# 239  7361  海科館  海科館                                      基隆市中正區長潭里
# 240  7362  八斗子  八斗子  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 241  7380  四腳亭  四腳亭                              新北市瑞芳區吉慶里中央路 65 號
# 242  7390   暖暖   暖暖                              基隆市暖暖區暖暖里暖暖街 51 號
#
# [243 rows x 4 columns]
